# %% [markdown]
# ## Imports, function definitions
#
# Note: DeepMoD does not work for python3.9

# %%
# pip install pysindy

# %%
# pip install DeePyMoD==2.1.0

# %%
# pip install --upgrade tensorflow

# %%
# pip install tensorflow-io

# %%
data_path = "datasets"
results_path = ""

# %%
from deepymod import DeepMoD

# %%
import matplotlib.pyplot as plt

# General imports
import numpy as np
import torch
import pandas as pd

# DeePyMoD imports
from deepymod import DeepMoD
from deepymod.data import Dataset, get_train_test_loader
from deepymod.data.samples import Subsample_random
from deepymod.data.burgers import burgers_delta
from deepymod.model.constraint import LeastSquares
from deepymod.model.func_approx import NN
from deepymod.model.library import Library1D
from deepymod.model.sparse_estimators import Threshold
from deepymod.training import train
from deepymod.training.sparsity_scheduler import Periodic, TrainTest, TrainTestPeriodic

if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"
print(device)

# Settings for reproducibility
np.random.seed(42)
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False


import pickle
def load_data(X,y):
    return torch.from_numpy(X).float(),torch.from_numpy(y).float()

def uxt_2D_to1D(u,x,t):
    '''
    Function for reshaping u,x and t
    '''
    t_reg=[]
    x_reg=[]
    for i in range(len(t)):
        for j in range(len(x)):
            t_reg.append(t[i])
            x_reg.append(x[j])
    u_reg = u.reshape((u.size, 1))

    return u_reg,x_reg,t_reg

descr = ['',
 'u_{x}',
 'u_{xx}',
 'u_{xxx}',
 'u',
 'uu_{x}',
 'uu_{xx}',
 'uu_{xxx}',
 'u^2',
 'u^2u_{x}',
 'u^2u_{xx}',
 'u^2u_{xxx}']

def return_pde(w, rhs_description=descr, ut = 'u_t'):
    pde = ut + ' = '
    first = True
    for i in range(len(w)):
        if w[i] != 0:
            if not first:
                pde = pde + ' + '
            pde = pde + "(%05f)" % (w[i].real) + rhs_description[i] 
            first = False
    return pde
# Out:
# cuda

# %% [markdown]
# ## Testing

# %%
# Simple PDE ut = 0.8ux

pred_coefficients=[]

snrs = ["No noise",20000,15000,10000,7500,5000,3000,2000,1000,800,500,300,200,100,90,80,70,60,50,40,30,20,10,8,6,5,4,3,2,1,0.9,0.8,0.75,0.7,0.6,0.5,0.4,0.3,0.25,0.2,0.1]
for j in range(len(snrs)):
    print("="*100)
    print("SNR = ",snrs[j])

    # Loading u,x,t
    path = data_path+"/4_"+str(j)+".pkl"
    file_to_read = open(path, "rb")
    data = pickle.load(file_to_read)

    # reshaping
    u_reg,x_reg,t_reg = uxt_2D_to1D(data["u"],data["x"],data["t"])
    X = np.vstack([t_reg,x_reg]).T
    y = u_reg

    # Deepmod
    preprocess_kwargs = {"noise_level": 0.0}
    load_kwargs = {"X": X, "y": y}
    dataset = Dataset(
    load_data,
    load_kwargs=load_kwargs,
    preprocess_kwargs=preprocess_kwargs,
    subsampler=Subsample_random,
    subsampler_kwargs={"number_of_samples": 5000},
    device=device,
    )
    train_dataloader, test_dataloader = get_train_test_loader(
    dataset, train_test_split=0.8
    )
    network = NN(2, [50, 50, 50,50], 1)
    library = Library1D(poly_order=2, diff_order=3) 
    estimator = Threshold(0.1) 
    sparsity_scheduler = TrainTestPeriodic(periodicity=50, patience=200, delta=1e-5) 
    constraint = LeastSquares() 
    model = DeepMoD(network, library, estimator, constraint).to(device)
    optimizer = torch.optim.Adam(model.parameters(), betas=(0.99, 0.99), amsgrad=True, lr=1e-3) 
    train(
      model,
      train_dataloader,
      test_dataloader,
      optimizer,
      sparsity_scheduler,
      exp_ID="Test",
      write_iterations=25,
      max_iterations=20000,
      delta=1e-4,
      patience=200,
    )

    w = list(model.constraint_coeffs()[0])
    w = [w[i][0].item() for i in range(len(w))]
    print("\nPredicted PDE: ", return_pde(w))
    pred_coefficients.append([snrs[j]]+list(w))
    
df_4 = pd.DataFrame(pred_coefficients, columns = ["SNR"]+descr )
df_4 = df_4[['SNR', '', 'u_{x}', 'u_{xx}', 'u_{xxx}', 'u',
       'u^2', 'uu_{x}', 'u^2u_{x}', 'uu_{xx}', 'u^2u_{xx}', 'uu_{xxx}',
       'u^2u_{xxx}']]
# Out:
# ====================================================================================================
# SNR =  No noise
# Dataset is using device:  cuda
# 2023-04-27 08:36:47.037447: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-27 08:36:47.554080: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#  12950  MSE: 6.66e-04  Reg: 4.81e-06  L1: 9.97e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.794377)u_{x}
# ====================================================================================================
# SNR =  20000
# Dataset is using device:  cuda
#  14575  MSE: 7.31e-04  Reg: 1.17e-05  L1: 9.92e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.809271)u_{x}
# ====================================================================================================
# SNR =  15000
# Dataset is using device:  cuda
#   9250  MSE: 7.47e-04  Reg: 6.42e-06  L1: 9.95e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.794112)u_{x}
# ====================================================================================================
# SNR =  10000
# Dataset is using device:  cuda
#  14000  MSE: 8.44e-04  Reg: 1.74e-05  L1: 1.02e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.789662)u_{x} + (-0.003269)u^2
# ====================================================================================================
# SNR =  7500
# Dataset is using device:  cuda
#   6475  MSE: 9.12e-04  Reg: 1.47e-05  L1: 9.95e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.712145)u_{x} + (-0.166944)uu_{x}
# ====================================================================================================
# SNR =  5000
# Dataset is using device:  cuda
#  11175  MSE: 9.71e-04  Reg: 1.38e-05  L1: 9.90e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.793748)u_{x}
# ====================================================================================================
# SNR =  3000
# Dataset is using device:  cuda
#  12175  MSE: 7.84e-04  Reg: 8.90e-06  L1: 9.93e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.795467)u_{x}
# ====================================================================================================
# SNR =  2000
# Dataset is using device:  cuda
#  11550  MSE: 1.06e-03  Reg: 1.35e-05  L1: 9.90e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.803259)u_{x}
# ====================================================================================================
# SNR =  1000
# Dataset is using device:  cuda
#   8975  MSE: 9.59e-04  Reg: 9.25e-06  L1: 9.93e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.800312)u_{x}
# ====================================================================================================
# SNR =  800
# Dataset is using device:  cuda
#  14075  MSE: 9.18e-04  Reg: 9.11e-06  L1: 9.93e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.807226)u_{x}
# ====================================================================================================
# SNR =  500
# Dataset is using device:  cuda
#   9650  MSE: 1.01e-03  Reg: 1.24e-05  L1: 9.91e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.797886)u_{x}
# ====================================================================================================
# SNR =  300
# Dataset is using device:  cuda
#   8500  MSE: 1.50e-03  Reg: 1.57e-05  L1: 9.89e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.797843)u_{x}
# ====================================================================================================
# SNR =  200
# Dataset is using device:  cuda
#  18000  MSE: 9.46e-04  Reg: 7.97e-06  L1: 9.94e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.796081)u_{x}
# ====================================================================================================
# SNR =  100
# Dataset is using device:  cuda
#   6350  MSE: 2.01e-03  Reg: 1.70e-05  L1: 9.95e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.697256)u_{x} + (-0.205945)uu_{x}
# ====================================================================================================
# SNR =  90
# Dataset is using device:  cuda
#  14650  MSE: 1.34e-03  Reg: 1.44e-05  L1: 9.90e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.790179)u_{x}
# ====================================================================================================
# SNR =  80
# Dataset is using device:  cuda
#  10925  MSE: 1.72e-03  Reg: 1.25e-05  L1: 9.91e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.805968)u_{x}
# ====================================================================================================
# SNR =  70
# Dataset is using device:  cuda
#  13800  MSE: 1.69e-03  Reg: 1.15e-05  L1: 9.91e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.801280)u_{x}
# ====================================================================================================
# SNR =  60
# Dataset is using device:  cuda
#   6750  MSE: 2.19e-03  Reg: 1.32e-05  L1: 9.90e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.798246)u_{x}
# ====================================================================================================
# SNR =  50
# Dataset is using device:  cuda
#  14675  MSE: 2.29e-03  Reg: 1.48e-05  L1: 9.89e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.791825)u_{x}
# ====================================================================================================
# SNR =  40
# Dataset is using device:  cuda
#  10100  MSE: 2.32e-03  Reg: 1.41e-05  L1: 9.90e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.791282)u_{x}
# ====================================================================================================
# SNR =  30
# Dataset is using device:  cuda
#   8075  MSE: 3.37e-03  Reg: 1.61e-05  L1: 9.88e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.787114)u_{x}
# ====================================================================================================
# SNR =  20
# Dataset is using device:  cuda
#  10025  MSE: 4.06e-03  Reg: 1.16e-05  L1: 9.91e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.795442)u_{x}
# ====================================================================================================
# SNR =  10
# Dataset is using device:  cuda
#   5575  MSE: 8.04e-03  Reg: 3.03e-05  L1: 1.10e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.707862)u_{x} + (-0.209035)u_{xxx} + (-0.180049)uu_{x}
# ====================================================================================================
# SNR =  8
# Dataset is using device:  cuda
#  13175  MSE: 8.45e-03  Reg: 4.04e-05  L1: 9.84e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.789882)u_{x} + (-0.001206)u^2
# ====================================================================================================
# SNR =  6
# Dataset is using device:  cuda
#  13350  MSE: 1.14e-02  Reg: 3.15e-05  L1: 9.79e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.784528)u_{x}
# ====================================================================================================
# SNR =  5
# Dataset is using device:  cuda
#   7175  MSE: 1.42e-02  Reg: 5.86e-05  L1: 9.66e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.690411)u_{x} + (-0.199419)uu_{x}
# ====================================================================================================
# SNR =  4
# Dataset is using device:  cuda
#  19975  MSE: 1.52e-02  Reg: 4.72e-05  L1: 2.64e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.800226)u_{x} + (0.225000)u_{xxx} + (-1.043801)uu_{xxx} + (0.840806)u^2u_{xxx}
# ====================================================================================================
# SNR =  3
# Dataset is using device:  cuda
#  19975  MSE: 2.11e-02  Reg: 5.93e-05  L1: 4.26e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.792951)u_{x} + (-0.105008)u_{xx} + (-0.012996)u_{xxx}
# ====================================================================================================
# SNR =  2
# Dataset is using device:  cuda
#  19975  MSE: 3.12e-02  Reg: 9.75e-05  L1: 1.75e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.733677)u_{x} + (-0.240215)uu_{xx} + (0.007009)uu_{xxx} + (-0.028759)u^2u_{xxx}
# ====================================================================================================
# SNR =  1
# Dataset is using device:  cuda
#  19975  MSE: 6.00e-02  Reg: 1.75e-04  L1: 3.15e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.588830)u_{x} + (-0.047274)u_{xxx} + (-0.806024)uu_{x} + (0.846205)u^2u_{x} + (0.044831)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.9
# Dataset is using device:  cuda
#   4450  MSE: 7.15e-02  Reg: 1.29e-04  L1: 1.13e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.765285)u_{x} + (-0.169441)u_{xxx}
# ====================================================================================================
# SNR =  0.8
# Dataset is using device:  cuda
#  19975  MSE: 7.63e-02  Reg: 3.54e-04  L1: 4.90e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.697513)u_{x} + (-0.048725)u_{xxx} + (-0.306673)uu_{xxx} + (0.412478)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.75
# Dataset is using device:  cuda
#  19150  MSE: 7.80e-02  Reg: 2.94e-04  L1: 8.97e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.735535)u_{x}
# ====================================================================================================
# SNR =  0.7
# Dataset is using device:  cuda
#  19975  MSE: 8.89e-02  Reg: 3.85e-04  L1: 1.72e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.709068)u_{x} + (0.043640)u_{xxx} + (-0.000384)u + (-0.379830)uu_{x}
# ====================================================================================================
# SNR =  0.6
# Dataset is using device:  cuda
#  19975  MSE: 1.03e-01  Reg: 4.33e-04  L1: 4.21e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.845427)u_{x} + (-0.019297)u_{xxx} + (0.328911)uu_{x} + (-0.228555)uu_{xx} + (-0.151276)uu_{xxx} + (0.253292)u^2u_{xx} + (0.170587)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.5
# Dataset is using device:  cuda
#  15550  MSE: 1.26e-01  Reg: 4.72e-04  L1: 1.07e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.752652)u_{x} + (-0.263795)uu_{xxx}
# ====================================================================================================
# SNR =  0.4
# Dataset is using device:  cuda
#  19975  MSE: 1.46e-01  Reg: 1.23e-03  L1: 2.77e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.806316)u_{x} + (-0.034909)u_{xxx} + (-0.069389)uu_{xxx} + (0.392464)u^2u_{x} + (0.100863)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.3
# Dataset is using device:  cuda
#  19975  MSE: 1.81e-01  Reg: 2.21e-03  L1: 9.26e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.807408)u_{x}
# ====================================================================================================
# SNR =  0.25
# Dataset is using device:  cuda
#   4700  MSE: 2.49e-01  Reg: 4.57e-04  L1: 8.93e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.825614)u_{x}
# ====================================================================================================
# SNR =  0.2
# Dataset is using device:  cuda
#  19975  MSE: 2.98e-01  Reg: 1.84e-03  L1: 2.68e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.833819)u_{x} + (-0.029842)u_{xxx} + (-0.037498)uu_{xxx} + (0.283473)u^2u_{x} + (0.067574)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.1
# Dataset is using device:  cuda
#  19975  MSE: 5.86e-01  Reg: 6.91e-03  L1: 1.71e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.704171)u_{x} + (-0.010443)u_{xxx} + (-0.008222)uu_{xxx}
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[8], line 63
#      59 df_4 = pd.DataFrame(pred_coefficients, columns = ["SNR"]+descr )
#      60 df_4 = df_4[['SNR', '', 'u_{x}', 'u_{xx}', 'u_{xxx}', 'u',
#      61        'u^2', 'uu_{x}', 'u^2u_{x}', 'uu_{xx}', 'u^2u_{xx}', 'uu_{xxx}',
#      62        'u^2u_{xxx}']]
# ---> 63 df_4.to_csv(results_path+"/simplepde_results.csv")
#      64 df_4
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/formats/format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/formats/csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: '/simplepde_results.csv'

# %%
df_4.to_csv(results_path+"simplepde_results.csv")
df_4
# Out:
#          SNR          u_{x}    u_{xx}   u_{xxx}         u       u^2    uu_{x}
# 0   No noise  0.0 -0.794377  0.000000  0.000000  0.000000  0.000000  0.000000  \
# 1      20000  0.0 -0.809271  0.000000  0.000000  0.000000  0.000000  0.000000
# 2      15000  0.0 -0.794112  0.000000  0.000000  0.000000  0.000000  0.000000
# 3      10000  0.0 -0.789662  0.000000  0.000000  0.000000 -0.003269  0.000000
# 4       7500  0.0 -0.712145  0.000000  0.000000  0.000000  0.000000 -0.166944
# 5       5000  0.0 -0.793748  0.000000  0.000000  0.000000  0.000000  0.000000
# 6       3000  0.0 -0.795467  0.000000  0.000000  0.000000  0.000000  0.000000
# 7       2000  0.0 -0.803259  0.000000  0.000000  0.000000  0.000000  0.000000
# 8       1000  0.0 -0.800312  0.000000  0.000000  0.000000  0.000000  0.000000
# 9        800  0.0 -0.807226  0.000000  0.000000  0.000000  0.000000  0.000000
# 10       500  0.0 -0.797886  0.000000  0.000000  0.000000  0.000000  0.000000
# 11       300  0.0 -0.797843  0.000000  0.000000  0.000000  0.000000  0.000000
# 12       200  0.0 -0.796081  0.000000  0.000000  0.000000  0.000000  0.000000
# 13       100  0.0 -0.697256  0.000000  0.000000  0.000000  0.000000 -0.205945
# 14        90  0.0 -0.790179  0.000000  0.000000  0.000000  0.000000  0.000000
# 15        80  0.0 -0.805968  0.000000  0.000000  0.000000  0.000000  0.000000
# 16        70  0.0 -0.801280  0.000000  0.000000  0.000000  0.000000  0.000000
# 17        60  0.0 -0.798246  0.000000  0.000000  0.000000  0.000000  0.000000
# 18        50  0.0 -0.791825  0.000000  0.000000  0.000000  0.000000  0.000000
# 19        40  0.0 -0.791282  0.000000  0.000000  0.000000  0.000000  0.000000
# 20        30  0.0 -0.787114  0.000000  0.000000  0.000000  0.000000  0.000000
# 21        20  0.0 -0.795442  0.000000  0.000000  0.000000  0.000000  0.000000
# 22        10  0.0 -0.707862  0.000000 -0.209035  0.000000  0.000000 -0.180049
# 23         8  0.0 -0.789882  0.000000  0.000000  0.000000 -0.001206  0.000000
# 24         6  0.0 -0.784528  0.000000  0.000000  0.000000  0.000000  0.000000
# 25         5  0.0 -0.690411  0.000000  0.000000  0.000000  0.000000 -0.199419
# 26         4  0.0 -0.800226  0.000000  0.225000  0.000000  0.000000  0.000000
# 27         3  0.0 -0.792951 -0.105008 -0.012996  0.000000  0.000000  0.000000
# 28         2  0.0 -0.733677  0.000000  0.000000  0.000000  0.000000  0.000000
# 29         1  0.0 -0.588830  0.000000 -0.047274  0.000000  0.000000 -0.806024
# 30       0.9  0.0 -0.765285  0.000000 -0.169441  0.000000  0.000000  0.000000
# 31       0.8  0.0 -0.697513  0.000000 -0.048725  0.000000  0.000000  0.000000
# 32      0.75  0.0 -0.735535  0.000000  0.000000  0.000000  0.000000  0.000000
# 33       0.7  0.0 -0.709068  0.000000  0.043640 -0.000384  0.000000 -0.379830
# 34       0.6  0.0 -0.845427  0.000000 -0.019297  0.000000  0.000000  0.328911
# 35       0.5  0.0 -0.752652  0.000000  0.000000  0.000000  0.000000  0.000000
# 36       0.4  0.0 -0.806316  0.000000 -0.034909  0.000000  0.000000  0.000000
# 37       0.3  0.0 -0.807408  0.000000  0.000000  0.000000  0.000000  0.000000
# 38      0.25  0.0 -0.825614  0.000000  0.000000  0.000000  0.000000  0.000000
# 39       0.2  0.0 -0.833819  0.000000 -0.029842  0.000000  0.000000  0.000000
# 40       0.1  0.0 -0.704171  0.000000 -0.010443  0.000000  0.000000  0.000000
#
#     u^2u_{x}   uu_{xx}  u^2u_{xx}  uu_{xxx}  u^2u_{xxx}
# 0   0.000000  0.000000   0.000000  0.000000    0.000000
# 1   0.000000  0.000000   0.000000  0.000000    0.000000
# 2   0.000000  0.000000   0.000000  0.000000    0.000000
# 3   0.000000  0.000000   0.000000  0.000000    0.000000
# 4   0.000000  0.000000   0.000000  0.000000    0.000000
# 5   0.000000  0.000000   0.000000  0.000000    0.000000
# 6   0.000000  0.000000   0.000000  0.000000    0.000000
# 7   0.000000  0.000000   0.000000  0.000000    0.000000
# 8   0.000000  0.000000   0.000000  0.000000    0.000000
# 9   0.000000  0.000000   0.000000  0.000000    0.000000
# 10  0.000000  0.000000   0.000000  0.000000    0.000000
# 11  0.000000  0.000000   0.000000  0.000000    0.000000
# 12  0.000000  0.000000   0.000000  0.000000    0.000000
# 13  0.000000  0.000000   0.000000  0.000000    0.000000
# 14  0.000000  0.000000   0.000000  0.000000    0.000000
# 15  0.000000  0.000000   0.000000  0.000000    0.000000
# 16  0.000000  0.000000   0.000000  0.000000    0.000000
# 17  0.000000  0.000000   0.000000  0.000000    0.000000
# 18  0.000000  0.000000   0.000000  0.000000    0.000000
# 19  0.000000  0.000000   0.000000  0.000000    0.000000
# 20  0.000000  0.000000   0.000000  0.000000    0.000000
# 21  0.000000  0.000000   0.000000  0.000000    0.000000
# 22  0.000000  0.000000   0.000000  0.000000    0.000000
# 23  0.000000  0.000000   0.000000  0.000000    0.000000
# 24  0.000000  0.000000   0.000000  0.000000    0.000000
# 25  0.000000  0.000000   0.000000  0.000000    0.000000
# 26  0.000000  0.000000   0.000000 -1.043801    0.840806
# 27  0.000000  0.000000   0.000000  0.000000    0.000000
# 28  0.000000 -0.240215   0.000000  0.007009   -0.028759
# 29  0.846205  0.000000   0.000000  0.000000    0.044831
# 30  0.000000  0.000000   0.000000  0.000000    0.000000
# 31  0.000000  0.000000   0.000000 -0.306673    0.412478
# 32  0.000000  0.000000   0.000000  0.000000    0.000000
# 33  0.000000  0.000000   0.000000  0.000000    0.000000
# 34  0.000000 -0.228555   0.253292 -0.151276    0.170587
# 35  0.000000  0.000000   0.000000 -0.263795    0.000000
# 36  0.392464  0.000000   0.000000 -0.069389    0.100863
# 37  0.000000  0.000000   0.000000  0.000000    0.000000
# 38  0.000000  0.000000   0.000000  0.000000    0.000000
# 39  0.283473  0.000000   0.000000 -0.037498    0.067574
# 40  0.000000  0.000000   0.000000 -0.008222    0.000000

# %%
# Heat equation ut = 0.8ux

pred_coefficients=[]

snrs = ["No noise",20000,15000,10000,7500,5000,3000,2000,1000,800,500,300,200,100,90,80,70,60,50,40,30,20,10,8,6,5,4,3,2,1,0.9,0.8,0.75,0.7,0.6,0.5,0.4,0.3,0.25,0.2,0.1]

for j in range(len(snrs)):
    print("="*100)
    print("SNR = ",snrs[j])

    # Loading u,x,t
    path = data_path+"/1_"+str(j)+".pkl"
    file_to_read = open(path, "rb")
    data = pickle.load(file_to_read)

    # reshaping
    u_reg,x_reg,t_reg = uxt_2D_to1D(data["u"],data["x"],data["t"])
    X = np.vstack([t_reg,x_reg]).T
    y = u_reg

    # Deepmod
    preprocess_kwargs = {"noise_level": 0.0}
    load_kwargs = {"X": X, "y": y}
    dataset = Dataset(
    load_data,
    load_kwargs=load_kwargs,
    preprocess_kwargs=preprocess_kwargs,
    subsampler=Subsample_random,
    subsampler_kwargs={"number_of_samples": 5000},
    device=device,
    )
    train_dataloader, test_dataloader = get_train_test_loader(
    dataset, train_test_split=0.8
    )
    network = NN(2, [50, 50, 50,50], 1)
    library = Library1D(poly_order=2, diff_order=3) 
    estimator = Threshold(0.1) 
    sparsity_scheduler = TrainTestPeriodic(periodicity=50, patience=200, delta=1e-5) 
    constraint = LeastSquares() 
    model = DeepMoD(network, library, estimator, constraint).to(device)
    optimizer = torch.optim.Adam(model.parameters(), betas=(0.99, 0.99), amsgrad=True, lr=1e-3) 
    train(
      model,
      train_dataloader,
      test_dataloader,
      optimizer,
      sparsity_scheduler,
      exp_ID="Test",
      write_iterations=25,
      max_iterations=20000,
      delta=1e-4,
      patience=200,
    )

    w = list(model.constraint_coeffs()[0])
    w = [w[i][0].item() for i in range(len(w))]
    print("\nPredicted PDE: ", return_pde(w))
    pred_coefficients.append([snrs[j]]+list(w))
    
df_1 = pd.DataFrame(pred_coefficients, columns = ["SNR"]+descr )
df_1 = df_1[['SNR', '', 'u_{x}', 'u_{xx}', 'u_{xxx}', 'u',
       'u^2', 'uu_{x}', 'u^2u_{x}', 'uu_{xx}', 'u^2u_{xx}', 'uu_{xxx}',
       'u^2u_{xxx}']]
df_1.to_csv(results_path+"heateqn_results.csv")
df_1
# Out:
# ====================================================================================================
# SNR =  No noise
# Dataset is using device:  cuda
#  19975  MSE: 3.24e+04  Reg: 5.17e-12  L1: 7.23e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.000001) + (-1322336.125000)u_{xx} + (-114419.859375)u_{xxx} + (-3128.190674)uu_{x} + (1476.700928)uu_{xx} + (-2584.203857)uu_{xxx} + (19.397884)u^2u_{x} + (41.689983)u^2u_{xx} + (20.424377)u^2u_{xxx}
# ====================================================================================================
# SNR =  20000
# Dataset is using device:  cuda
#  19975  MSE: 1.00e+05  Reg: 9.78e-13  L1: 5.12e+07 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (5.750172) + (292119.812500)u_{x} + (55139.574219)u_{xx} + (-11525.343750)u_{xxx} + (-0.487081)u + (16059.167969)uu_{x} + (4175.581055)uu_{xx} + (-1085.629639)uu_{xxx} + (0.009433)u^2 + (-1754.319092)u^2u_{x} + (-393.778229)u^2u_{xx} + (93.958221)u^2u_{xxx}
# ====================================================================================================
# SNR =  15000
# Dataset is using device:  cuda
#  19975  MSE: 9.67e+04  Reg: 2.97e-15  L1: 7.64e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-443215.500000)u_{xx} + (-39198.375000)u_{xxx} + (-1291.824219)uu_{x} + (-6109.179688)uu_{xx} + (2684.224609)uu_{xxx} + (56.845459)u^2u_{x} + (1127.136719)u^2u_{xx} + (-42.213654)u^2u_{xxx}
# ====================================================================================================
# SNR =  10000
# Dataset is using device:  cuda
#  19975  MSE: 9.94e+04  Reg: 2.62e-13  L1: 6.46e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.206202) + (465370.312500)u_{x} + (145080.937500)u_{xx} + (-172460.203125)u_{xxx} + (0.025291)u + (-3280.689453)uu_{x} + (6948.091797)uu_{xx} + (-5683.994629)uu_{xxx} + (-0.001781)u^2 + (-1000.045593)u^2u_{x} + (-710.431641)u^2u_{xx} + (715.696838)u^2u_{xxx}
# ====================================================================================================
# SNR =  7500
# Dataset is using device:  cuda
#   6800  MSE: 2.11e+04  Reg: 3.85e-12  L1: 1.21e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.476693)u_{x} + (0.071025)u_{xxx} + (-0.000000)u
# ====================================================================================================
# SNR =  5000
# Dataset is using device:  cuda
#   3100  MSE: 1.01e+05  Reg: 2.47e-14  L1: 7.25e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.000000) + (1332130.000000)u_{x} + (829817.187500)u_{xx} + (28507.621094)uu_{x} + (-27350.873047)uu_{xx} + (-2020.706055)uu_{xxx} + (-5475.611816)u^2u_{x} + (-961.510986)u^2u_{xx} + (109.722748)u^2u_{xxx}
# ====================================================================================================
# SNR =  3000
# Dataset is using device:  cuda
#  19975  MSE: 5.77e+04  Reg: 1.51e-15  L1: 1.78e+05 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.000000) + (-0.553354)u_{xx} + (-2365.003906)uu_{x} + (24.304138)u^2u_{x}
# ====================================================================================================
# SNR =  2000
# Dataset is using device:  cuda
#  19975  MSE: 8.15e+04  Reg: 5.18e-13  L1: 7.03e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (1.170066) + (639645.750000)u_{x} + (246669.328125)u_{xx} + (-143291.281250)u_{xxx} + (-0.007290)u + (2695.617188)uu_{x} + (-59752.187500)uu_{xx} + (-8079.178711)uu_{xxx} + (-0.000340)u^2 + (-322.464661)u^2u_{x} + (1118.494873)u^2u_{xx} + (225.065414)u^2u_{xxx}
# ====================================================================================================
# SNR =  1000
# Dataset is using device:  cuda
#  19975  MSE: 5.86e+04  Reg: 8.02e-13  L1: 1.65e+07 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.071557) + (666387.062500)u_{x} + (91629.015625)u_{xx} + (-413062.812500)u_{xxx} + (0.040515)u + (-2076.195312)uu_{x} + (160.769531)uu_{xx} + (-6405.975586)uu_{xxx} + (-0.000418)u^2 + (-51.854294)u^2u_{x} + (-11.822596)u^2u_{xx} + (113.036819)u^2u_{xxx}
# ====================================================================================================
# SNR =  800
# Dataset is using device:  cuda
#  19975  MSE: 5.51e+04  Reg: 2.30e-13  L1: 1.18e+07 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (7.349164) + (288982.125000)u_{x} + (39105.820312)u_{xx} + (-19633.312500)u_{xxx} + (-0.098560)u + (4181.720703)uu_{x} + (-41.922241)uu_{xx} + (256.043823)uu_{xxx} + (0.000273)u^2 + (-65.896660)u^2u_{x} + (-3.137567)u^2u_{xx} + (-0.659426)u^2u_{xxx}
# ====================================================================================================
# SNR =  500
# Dataset is using device:  cuda
#  19975  MSE: 8.69e+04  Reg: 2.82e-13  L1: 5.17e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.000000) + (1001139.625000)u_{x} + (6858.708008)u_{xxx} + (-25261.835938)uu_{x} + (-1639.604492)uu_{xx} + (-3491.628418)uu_{xxx} + (41.372143)u^2u_{xx} + (83.737556)u^2u_{xxx}
# ====================================================================================================
# SNR =  300
# Dataset is using device:  cuda
#  19975  MSE: 1.00e+05  Reg: 1.41e-11  L1: 1.60e+08 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.122715) + (-403672.531250)u_{x} + (-2128.457031)u_{xx} + (4669.163086)u_{xxx} + (0.018909)u + (32152.410156)uu_{x} + (-18860.367188)uu_{xx} + (-45.493591)uu_{xxx} + (-0.001482)u^2 + (-518.963074)u^2u_{x} + (1084.964233)u^2u_{xx} + (-12.654327)u^2u_{xxx}
# ====================================================================================================
# SNR =  200
# Dataset is using device:  cuda
#  19975  MSE: 9.65e+04  Reg: 2.43e-14  L1: 7.09e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.825874) + (-1614665.125000)u_{x} + (694711.250000)u_{xx} + (5778.312500)u_{xxx} + (0.027533)u + (52927.281250)uu_{x} + (5343.280273)uu_{xx} + (-2109.117676)uu_{xxx} + (-0.002554)u^2 + (574.811279)u^2u_{x} + (-1410.776855)u^2u_{xx} + (77.384094)u^2u_{xxx}
# ====================================================================================================
# SNR =  100
# Dataset is using device:  cuda
#   1000  MSE: 9.77e+04  Reg: 2.07e-16  L1: 9.95e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.231665)u_{x} + (-0.210578)u_{xx}
# ====================================================================================================
# SNR =  90
# Dataset is using device:  cuda
#  19975  MSE: 9.54e+03  Reg: 6.11e-12  L1: 5.49e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-283.035095) + (974171.000000)u_{x} + (133489.218750)u_{xx} + (-143200.578125)u_{xxx} + (2.236208)u + (276.219116)uu_{x} + (-867.824341)uu_{xx} + (-226.004242)uu_{xxx} + (-0.004408)u^2 + (-14.924021)u^2u_{x} + (1.373750)u^2u_{xx} + (2.893648)u^2u_{xxx}
# ====================================================================================================
# SNR =  80
# Dataset is using device:  cuda
#  19975  MSE: 8.13e+04  Reg: 8.45e-13  L1: 2.28e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.000000) + (603227.000000)u_{xx} + (-30736.093750)uu_{x} + (-8477.885742)uu_{xx} + (596.665161)u^2u_{x} + (-62.747757)u^2u_{xx}
# ====================================================================================================
# SNR =  70
# Dataset is using device:  cuda
#  19975  MSE: 9.82e+04  Reg: 2.35e-15  L1: 6.18e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.000000) + (309701.593750)u_{xx} + (5489.741211)uu_{x} + (15124.490234)uu_{xx} + (-253.930099)u^2u_{x} + (-1362.205566)u^2u_{xx}
# ====================================================================================================
# SNR =  60
# Dataset is using device:  cuda
#  19975  MSE: 7.33e+04  Reg: 3.60e-13  L1: 1.33e+07 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-564707.062500)u_{xx} + (-206162.953125)u_{xxx} + (-47250.218750)uu_{x} + (17120.625000)uu_{xx} + (905.598145)uu_{xxx} + (730.839905)u^2u_{x} + (-129.711243)u^2u_{xx} + (35.315475)u^2u_{xxx}
# ====================================================================================================
# SNR =  50
# Dataset is using device:  cuda
#  19975  MSE: 7.64e+03  Reg: 1.32e-10  L1: 6.48e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (1.316793) + (676343.500000)u_{x} + (-29215.363281)u_{xx} + (-20247.236328)u_{xxx} + (-0.001990)u + (-431.067688)uu_{x} + (1618.871094)uu_{xx} + (41.721054)uu_{xxx} + (-0.000009)u^2 + (-6.913899)u^2u_{x} + (-5.353077)u^2u_{xx} + (0.105202)u^2u_{xxx}
# ====================================================================================================
# SNR =  40
# Dataset is using device:  cuda
#  19975  MSE: 1.02e+05  Reg: 2.51e-16  L1: 1.33e+07 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (177468.062500)u_{x} + (-19203.304688)u_{xx} + (25371.734375)u_{xxx} + (-27079.546875)uu_{x} + (-3877.926514)uu_{xx} + (-1698.848633)uu_{xxx} + (1010.993652)u^2u_{x} + (334.212158)u^2u_{xx} + (2.974152)u^2u_{xxx}
# ====================================================================================================
# SNR =  30
# Dataset is using device:  cuda
#   2900  MSE: 5.73e+04  Reg: 9.49e-15  L1: 9.90e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.101511)u_{x} + (-0.174682)u_{xx}
# ====================================================================================================
# SNR =  20
# Dataset is using device:  cuda
#  19975  MSE: 1.02e+05  Reg: 1.54e-13  L1: 1.05e+07 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.000000) + (784711.375000)u_{xx} + (72742.015625)uu_{x} + (-48781.957031)uu_{xx} + (-4612.334473)u^2u_{x} + (-61.759411)u^2u_{xx}
# ====================================================================================================
# SNR =  10
# Dataset is using device:  cuda
#  19975  MSE: 8.58e+04  Reg: 1.98e-12  L1: 4.40e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.000000) + (-160159.250000)u_{xx} + (45001.828125)u_{xxx} + (-4204.230469)uu_{x} + (-4291.642578)uu_{xx} + (1095.663086)uu_{xxx} + (95.200775)u^2u_{x} + (179.302795)u^2u_{xx} + (-47.885910)u^2u_{xxx}
# ====================================================================================================
# SNR =  8
# Dataset is using device:  cuda
#  19975  MSE: 1.02e+05  Reg: 2.45e-14  L1: 6.56e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (406766.718750)u_{xx} + (-47543.085938)u_{xxx} + (-3505.642578)uu_{x} + (-26835.833984)uu_{xx} + (2414.245117)uu_{xxx} + (205.577820)u^2u_{x} + (174.876465)u^2u_{xx} + (21.920185)u^2u_{xxx}
# ====================================================================================================
# SNR =  6
# Dataset is using device:  cuda
#  19975  MSE: 1.02e+05  Reg: 1.03e-14  L1: 8.03e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-1164325.375000)u_{xx} + (-230249.062500)u_{xxx} + (-23055.406250)uu_{x} + (39754.687500)uu_{xx} + (27479.906250)uu_{xxx} + (1402.530762)u^2u_{x} + (1890.382812)u^2u_{xx} + (-819.615356)u^2u_{xxx}
# ====================================================================================================
# SNR =  5
# Dataset is using device:  cuda
#  19975  MSE: 9.07e+04  Reg: 2.29e-13  L1: 1.77e+07 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.000000) + (4175873.000000)u_{xx} + (-568487.375000)u_{xxx} + (56071.714844)uu_{x} + (-78877.484375)uu_{xx} + (22969.615234)uu_{xxx} + (-1559.305176)u^2u_{x} + (-1035.885254)u^2u_{xx} + (-199.127563)u^2u_{xxx}
# ====================================================================================================
# SNR =  4
# Dataset is using device:  cuda
#  19975  MSE: 4.94e+04  Reg: 6.48e-14  L1: 7.29e+04 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-4186.207031)u_{xxx} + (-500.213867)uu_{x} + (-83.271606)uu_{xxx} + (-0.000000)u^2 + (4.191936)u^2u_{x} + (0.000004)u^2u_{xx} + (0.991878)u^2u_{xxx}
# ====================================================================================================
# SNR =  3
# Dataset is using device:  cuda
#  19975  MSE: 1.01e+05  Reg: 2.40e-14  L1: 3.52e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.000000) + (-267446.218750)u_{x} + (-82869.421875)u_{xx} + (-6468.984375)u_{xxx} + (-5991.242188)uu_{x} + (668.698242)uu_{xx} + (282.385498)uu_{xxx} + (924.841064)u^2u_{x} + (163.688675)u^2u_{xx} + (1.576752)u^2u_{xxx}
# ====================================================================================================
# SNR =  2
# Dataset is using device:  cuda
#  19975  MSE: 1.00e+05  Reg: 7.81e-16  L1: 1.04e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.000000) + (-425363.500000)u_{xx} + (2839.562500)uu_{x} + (10997.490234)uu_{xx} + (-131.935059)u^2u_{x} + (407.298950)u^2u_{xx}
# ====================================================================================================
# SNR =  1
# Dataset is using device:  cuda
#  19975  MSE: 1.18e+04  Reg: 5.62e-08  L1: 2.84e+07 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (12.093227) + (3812691.500000)u_{x} + (-148428.281250)u_{xx} + (85651.234375)u_{xxx} + (-0.421709)u + (-14201.386719)uu_{x} + (1999.968750)uu_{xx} + (-94.295959)uu_{xxx} + (0.001222)u^2 + (6.499626)u^2u_{x} + (-4.869968)u^2u_{xx} + (-0.570993)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.9
# Dataset is using device:  cuda
#  19975  MSE: 9.40e+04  Reg: 3.93e-13  L1: 5.20e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.000000) + (-626455.500000)u_{xx} + (83019.085938)u_{xxx} + (9669.363281)uu_{x} + (34784.648438)uu_{xx} + (1238.586304)uu_{xxx} + (-252.533173)u^2u_{x} + (-481.167725)u^2u_{xx} + (-88.973892)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.8
# Dataset is using device:  cuda
#   1825  MSE: 1.08e+05  Reg: 5.75e-14  L1: 1.03e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.000000) + (0.322963)u_{xxx}
# ====================================================================================================
# SNR =  0.75
# Dataset is using device:  cuda
#  19975  MSE: 1.07e+05  Reg: 5.75e-14  L1: 9.71e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.274899) + (-26322.796875)u_{x} + (113099.031250)u_{xx} + (-54029.023438)u_{xxx} + (0.088915)u + (18765.796875)uu_{x} + (-19896.640625)uu_{xx} + (-481.549988)uu_{xxx} + (-0.003719)u^2 + (-862.094666)u^2u_{x} + (706.513733)u^2u_{xx} + (155.387238)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.7
# Dataset is using device:  cuda
#   1675  MSE: 1.05e+05  Reg: 5.96e-14  L1: 1.32e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.000000) + (0.195237)u_{xxx} + (-0.016918)uu_{x}
# ====================================================================================================
# SNR =  0.6
# Dataset is using device:  cuda
#  19975  MSE: 1.56e+04  Reg: 4.62e-12  L1: 8.67e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-2.607899) + (-653552.250000)u_{x} + (-261255.828125)u_{xx} + (1480496.375000)u_{xxx} + (0.104767)u + (-3942.906982)uu_{x} + (-5241.236328)uu_{xx} + (-919.384277)uu_{xxx} + (-0.000309)u^2 + (19.362926)u^2u_{x} + (19.492519)u^2u_{xx} + (-12.274371)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.5
# Dataset is using device:  cuda
#  19975  MSE: 8.25e+04  Reg: 9.32e-12  L1: 1.56e+07 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.293469) + (135649.750000)u_{x} + (147681.781250)u_{xx} + (-9129.132812)u_{xxx} + (0.000657)u + (19033.435547)uu_{x} + (1320.551270)uu_{xx} + (-1135.241089)uu_{xxx} + (0.000054)u^2 + (-308.454559)u^2u_{x} + (-51.165016)u^2u_{xx} + (18.621174)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.4
# Dataset is using device:  cuda
#   1150  MSE: 1.10e+05  Reg: 3.84e-16  L1: 9.96e-01 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.310422)u_{x} + (-0.168134)u_{xx}
# ====================================================================================================
# SNR =  0.3
# Dataset is using device:  cuda
#  19975  MSE: 1.17e+05  Reg: 5.09e-12  L1: 4.94e+07 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.201198) + (-3410558.750000)u_{x} + (-437365.500000)u_{xx} + (210434.843750)u_{xxx} + (0.199667)u + (79779.023438)uu_{x} + (-9120.220703)uu_{xx} + (-13253.279297)uu_{xxx} + (-0.009317)u^2 + (4302.939453)u^2u_{x} + (1501.770142)u^2u_{xx} + (143.478638)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.25
# Dataset is using device:  cuda
#  19975  MSE: 4.48e+04  Reg: 1.25e-11  L1: 6.22e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-2.204405) + (606684.937500)u_{x} + (-475918.687500)u_{xx} + (-4122.917969)u_{xxx} + (0.060912)u + (3147.158203)uu_{x} + (5130.177246)uu_{xx} + (-1036.940796)uu_{xxx} + (-0.000252)u^2 + (-31.589275)u^2u_{x} + (-13.777807)u^2u_{xx} + (5.367717)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.2
# Dataset is using device:  cuda
#  19975  MSE: 1.31e+05  Reg: 1.69e-13  L1: 4.57e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.000000) + (-679179.187500)u_{xx} + (-358749.750000)uu_{x} + (-10331.160156)uu_{xx} + (20982.556641)u^2u_{x} + (2927.612305)u^2u_{xx}
# ====================================================================================================
# SNR =  0.1
# Dataset is using device:  cuda
#  19975  MSE: 1.60e+05  Reg: 2.06e-14  L1: 8.22e+06 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.000000) + (-559988.875000)u_{x} + (-0.182595)u_{xx} + (-46369.335938)u_{xxx} + (30721.419922)uu_{x} + (2543.866211)uu_{xxx}
#          SNR                       u_{x}        u_{xx}       u_{xxx}
# 0   No noise  6.227964e-07  0.000000e+00 -1.322336e+06 -1.144199e+05  \
# 1      20000  5.750172e+00  2.921198e+05  5.513957e+04 -1.152534e+04
# 2      15000  0.000000e+00  0.000000e+00 -4.432155e+05 -3.919838e+04
# 3      10000  2.062016e-01  4.653703e+05  1.450809e+05 -1.724602e+05
# 4       7500  0.000000e+00 -4.766926e-01  0.000000e+00  7.102510e-02
# 5       5000 -6.403378e-08  1.332130e+06  8.298172e+05  0.000000e+00
# 6       3000  1.435613e-08  0.000000e+00 -5.533544e-01  0.000000e+00
# 7       2000  1.170066e+00  6.396458e+05  2.466693e+05 -1.432913e+05
# 8       1000 -7.155679e-02  6.663871e+05  9.162902e+04 -4.130628e+05
# 9        800  7.349164e+00  2.889821e+05  3.910582e+04 -1.963331e+04
# 10       500 -1.702613e-07  1.001140e+06  0.000000e+00  6.858708e+03
# 11       300  1.227145e-01 -4.036725e+05 -2.128457e+03  4.669163e+03
# 12       200  8.258740e-01 -1.614665e+06  6.947112e+05  5.778312e+03
# 13       100  0.000000e+00  2.316653e-01 -2.105785e-01  0.000000e+00
# 14        90 -2.830351e+02  9.741710e+05  1.334892e+05 -1.432006e+05
# 15        80  2.587941e-07  0.000000e+00  6.032270e+05  0.000000e+00
# 16        70 -2.781786e-08  0.000000e+00  3.097016e+05  0.000000e+00
# 17        60  0.000000e+00  0.000000e+00 -5.647071e+05 -2.061630e+05
# 18        50  1.316793e+00  6.763435e+05 -2.921536e+04 -2.024724e+04
# 19        40  0.000000e+00  1.774681e+05 -1.920330e+04  2.537173e+04
# 20        30  0.000000e+00  1.015111e-01 -1.746825e-01  0.000000e+00
# 21        20  1.019316e-07  0.000000e+00  7.847114e+05  0.000000e+00
# 22        10  9.297008e-08  0.000000e+00 -1.601592e+05  4.500183e+04
# 23         8  0.000000e+00  0.000000e+00  4.067667e+05 -4.754309e+04
# 24         6  0.000000e+00  0.000000e+00 -1.164325e+06 -2.302491e+05
# 25         5 -4.148556e-08  0.000000e+00  4.175873e+06 -5.684874e+05
# 26         4  0.000000e+00  0.000000e+00  0.000000e+00 -4.186207e+03
# 27         3 -5.392526e-08 -2.674462e+05 -8.286942e+04 -6.468984e+03
# 28         2 -3.645670e-09  0.000000e+00 -4.253635e+05  0.000000e+00
# 29         1  1.209323e+01  3.812692e+06 -1.484283e+05  8.565123e+04
# 30       0.9  1.795368e-07  0.000000e+00 -6.264555e+05  8.301909e+04
# 31       0.8 -1.173287e-07  0.000000e+00  0.000000e+00  3.229628e-01
# 32      0.75 -2.748992e-01 -2.632280e+04  1.130990e+05 -5.402902e+04
# 33       0.7  1.165187e-07  0.000000e+00  0.000000e+00  1.952371e-01
# 34       0.6 -2.607899e+00 -6.535522e+05 -2.612558e+05  1.480496e+06
# 35       0.5 -2.934695e-01  1.356498e+05  1.476818e+05 -9.129133e+03
# 36       0.4  0.000000e+00  3.104219e-01 -1.681341e-01  0.000000e+00
# 37       0.3 -2.011980e-01 -3.410559e+06 -4.373655e+05  2.104348e+05
# 38      0.25 -2.204405e+00  6.066849e+05 -4.759187e+05 -4.122918e+03
# 39       0.2  1.794535e-07  0.000000e+00 -6.791792e+05  0.000000e+00
# 40       0.1  5.957266e-08 -5.599889e+05 -1.825952e-01 -4.636934e+04
#
#                u           u^2         uu_{x}      u^2u_{x}       uu_{xx}
# 0   0.000000e+00  0.000000e+00   -3128.190674     19.397884   1476.700928  \
# 1  -4.870806e-01  9.432853e-03   16059.167969  -1754.319092   4175.581055
# 2   0.000000e+00  0.000000e+00   -1291.824219     56.845459  -6109.179688
# 3   2.529142e-02 -1.780769e-03   -3280.689453  -1000.045593   6948.091797
# 4  -2.603607e-09  0.000000e+00       0.000000      0.000000      0.000000
# 5   0.000000e+00  0.000000e+00   28507.621094  -5475.611816 -27350.873047
# 6   0.000000e+00  0.000000e+00   -2365.003906     24.304138      0.000000
# 7  -7.289503e-03 -3.400256e-04    2695.617188   -322.464661 -59752.187500
# 8   4.051483e-02 -4.181212e-04   -2076.195312    -51.854294    160.769531
# 9  -9.855951e-02  2.726722e-04    4181.720703    -65.896660    -41.922241
# 10  0.000000e+00  0.000000e+00  -25261.835938      0.000000  -1639.604492
# 11  1.890926e-02 -1.481719e-03   32152.410156   -518.963074 -18860.367188
# 12  2.753269e-02 -2.553624e-03   52927.281250    574.811279   5343.280273
# 13  0.000000e+00  0.000000e+00       0.000000      0.000000      0.000000
# 14  2.236208e+00 -4.408244e-03     276.219116    -14.924021   -867.824341
# 15  0.000000e+00  0.000000e+00  -30736.093750    596.665161  -8477.885742
# 16  0.000000e+00  0.000000e+00    5489.741211   -253.930099  15124.490234
# 17  0.000000e+00  0.000000e+00  -47250.218750    730.839905  17120.625000
# 18 -1.990494e-03 -9.394915e-06    -431.067688     -6.913899   1618.871094
# 19  0.000000e+00  0.000000e+00  -27079.546875   1010.993652  -3877.926514
# 20  0.000000e+00  0.000000e+00       0.000000      0.000000      0.000000
# 21  0.000000e+00  0.000000e+00   72742.015625  -4612.334473 -48781.957031
# 22  0.000000e+00  0.000000e+00   -4204.230469     95.200775  -4291.642578
# 23  0.000000e+00  0.000000e+00   -3505.642578    205.577820 -26835.833984
# 24  0.000000e+00  0.000000e+00  -23055.406250   1402.530762  39754.687500
# 25  0.000000e+00  0.000000e+00   56071.714844  -1559.305176 -78877.484375
# 26  0.000000e+00 -3.077203e-12    -500.213867      4.191936      0.000000
# 27  0.000000e+00  0.000000e+00   -5991.242188    924.841064    668.698242
# 28  0.000000e+00  0.000000e+00    2839.562500   -131.935059  10997.490234
# 29 -4.217092e-01  1.222342e-03  -14201.386719      6.499626   1999.968750
# 30  0.000000e+00  0.000000e+00    9669.363281   -252.533173  34784.648438
# 31  0.000000e+00  0.000000e+00       0.000000      0.000000      0.000000
# 32  8.891508e-02 -3.718880e-03   18765.796875   -862.094666 -19896.640625
# 33  0.000000e+00  0.000000e+00      -0.016918      0.000000      0.000000
# 34  1.047674e-01 -3.091277e-04   -3942.906982     19.362926  -5241.236328
# 35  6.572993e-04  5.352887e-05   19033.435547   -308.454559   1320.551270
# 36  0.000000e+00  0.000000e+00       0.000000      0.000000      0.000000
# 37  1.996671e-01 -9.317111e-03   79779.023438   4302.939453  -9120.220703
# 38  6.091224e-02 -2.523201e-04    3147.158203    -31.589275   5130.177246
# 39  0.000000e+00  0.000000e+00 -358749.750000  20982.556641 -10331.160156
# 40  0.000000e+00  0.000000e+00   30721.419922      0.000000      0.000000
#
#       u^2u_{xx}      uu_{xxx}  u^2u_{xxx}
# 0     41.689983  -2584.203857   20.424377
# 1   -393.778229  -1085.629639   93.958221
# 2   1127.136719   2684.224609  -42.213654
# 3   -710.431641  -5683.994629  715.696838
# 4      0.000000      0.000000    0.000000
# 5   -961.510986  -2020.706055  109.722748
# 6      0.000000      0.000000    0.000000
# 7   1118.494873  -8079.178711  225.065414
# 8    -11.822596  -6405.975586  113.036819
# 9     -3.137567    256.043823   -0.659426
# 10    41.372143  -3491.628418   83.737556
# 11  1084.964233    -45.493591  -12.654327
# 12 -1410.776855  -2109.117676   77.384094
# 13     0.000000      0.000000    0.000000
# 14     1.373750   -226.004242    2.893648
# 15   -62.747757      0.000000    0.000000
# 16 -1362.205566      0.000000    0.000000
# 17  -129.711243    905.598145   35.315475
# 18    -5.353077     41.721054    0.105202
# 19   334.212158  -1698.848633    2.974152
# 20     0.000000      0.000000    0.000000
# 21   -61.759411      0.000000    0.000000
# 22   179.302795   1095.663086  -47.885910
# 23   174.876465   2414.245117   21.920185
# 24  1890.382812  27479.906250 -819.615356
# 25 -1035.885254  22969.615234 -199.127563
# 26     0.000004    -83.271606    0.991878
# 27   163.688675    282.385498    1.576752
# 28   407.298950      0.000000    0.000000
# 29    -4.869968    -94.295959   -0.570993
# 30  -481.167725   1238.586304  -88.973892
# 31     0.000000      0.000000    0.000000
# 32   706.513733   -481.549988  155.387238
# 33     0.000000      0.000000    0.000000
# 34    19.492519   -919.384277  -12.274371
# 35   -51.165016  -1135.241089   18.621174
# 36     0.000000      0.000000    0.000000
# 37  1501.770142 -13253.279297  143.478638
# 38   -13.777807  -1036.940796    5.367717
# 39  2927.612305      0.000000    0.000000
# 40     0.000000   2543.866211    0.000000

# %%
# Burgers eqn ut = -1uux +0.1uxx

pred_coefficients=[]

snrs = ["No noise",20000,15000,10000,7500,5000,3000,2000,1000,800,500,300,200,100,90,80,70,60,50,40,30,20,10,8,6,5,4,3,2,1,0.9,0.8,0.75,0.7,0.6,0.5,0.4,0.3,0.25,0.2,0.1]

for j in range(len(snrs)):
    print("="*100)
    print("SNR = ",snrs[j])

    # Loading u,x,t
    path = data_path+"/2_"+str(j)+".pkl"
    file_to_read = open(path, "rb")
    data = pickle.load(file_to_read)

    # reshaping
    u_reg,x_reg,t_reg = uxt_2D_to1D(data["u"],data["x"],data["t"])
    X = np.vstack([t_reg,x_reg]).T
    y = u_reg

    # Deepmod
    preprocess_kwargs = {"noise_level": 0.0}
    load_kwargs = {"X": X, "y": y}
    dataset = Dataset(
    load_data,
    load_kwargs=load_kwargs,
    preprocess_kwargs=preprocess_kwargs,
    subsampler=Subsample_random,
    subsampler_kwargs={"number_of_samples": 5000},
    device=device,
    )
    train_dataloader, test_dataloader = get_train_test_loader(
    dataset, train_test_split=0.8
    )
    network = NN(2, [50, 50, 50,50], 1)
    library = Library1D(poly_order=2, diff_order=3) 
    estimator = Threshold(0.1) 
    sparsity_scheduler = TrainTestPeriodic(periodicity=50, patience=200, delta=1e-5) 
    constraint = LeastSquares() 
    model = DeepMoD(network, library, estimator, constraint).to(device)
    optimizer = torch.optim.Adam(model.parameters(), betas=(0.99, 0.99), amsgrad=True, lr=1e-3) 
    train(
      model,
      train_dataloader,
      test_dataloader,
      optimizer,
      sparsity_scheduler,
      exp_ID="Test",
      write_iterations=25,
      max_iterations=20000,
      delta=1e-4,
      patience=200,
    )

    w = list(model.constraint_coeffs()[0])
    w = [w[i][0].item() for i in range(len(w))]
    print("\nPredicted PDE: ", return_pde(w))
    pred_coefficients.append([snrs[j]]+list(w))
    
df_2 = pd.DataFrame(pred_coefficients, columns = ["SNR"]+descr )
df_2 = df_2[['SNR', '', 'u_{x}', 'u_{xx}', 'u_{xxx}', 'u',
       'u^2', 'uu_{x}', 'u^2u_{x}', 'uu_{xx}', 'u^2u_{xx}', 'uu_{xxx}',
       'u^2u_{xxx}']]
df_2.to_csv(results_path+"burgerseqn_results.csv")
df_2
# Out:
# ====================================================================================================
# SNR =  No noise
# Dataset is using device:  cuda
#   6225  MSE: 2.76e-06  Reg: 6.87e-06  L1: 1.42e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.098428)u_{xx} + (-0.992248)uu_{x}
# ====================================================================================================
# SNR =  20000
# Dataset is using device:  cuda
#  19975  MSE: 5.43e-06  Reg: 6.48e-06  L1: 1.42e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.099912)u_{xx} + (-0.991904)uu_{x}
# ====================================================================================================
# SNR =  15000
# Dataset is using device:  cuda
#  19975  MSE: 5.08e-06  Reg: 4.30e-06  L1: 1.52e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.098517)u_{xx} + (-0.995592)uu_{x}
# ====================================================================================================
# SNR =  10000
# Dataset is using device:  cuda
#  13525  MSE: 4.44e-06  Reg: 3.07e-06  L1: 1.48e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.099015)u_{xx} + (-0.995755)uu_{x}
# ====================================================================================================
# SNR =  7500
# Dataset is using device:  cuda
#  16800  MSE: 7.75e-06  Reg: 7.52e-06  L1: 1.48e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.099128)u_{xx} + (-0.993309)uu_{x}
# ====================================================================================================
# SNR =  5000
# Dataset is using device:  cuda
#   9225  MSE: 9.90e-06  Reg: 6.21e-06  L1: 1.46e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.099237)u_{xx} + (-0.988658)uu_{x}
# ====================================================================================================
# SNR =  3000
# Dataset is using device:  cuda
#  11325  MSE: 1.35e-05  Reg: 7.84e-06  L1: 1.43e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.098146)u_{xx} + (-0.989801)uu_{x}
# ====================================================================================================
# SNR =  2000
# Dataset is using device:  cuda
#  15175  MSE: 2.09e-05  Reg: 6.54e-06  L1: 1.36e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.098584)u_{xx} + (-0.987220)uu_{x}
# ====================================================================================================
# SNR =  1000
# Dataset is using device:  cuda
#  19025  MSE: 3.66e-05  Reg: 7.04e-06  L1: 1.48e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.100100)u_{xx} + (-0.984485)uu_{x}
# ====================================================================================================
# SNR =  800
# Dataset is using device:  cuda
#  13700  MSE: 4.47e-05  Reg: 6.93e-06  L1: 1.44e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.098812)u_{xx} + (-0.986109)uu_{x}
# ====================================================================================================
# SNR =  500
# Dataset is using device:  cuda
#  19975  MSE: 6.93e-05  Reg: 6.18e-06  L1: 1.79e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.097645)u_{xx} + (-1.130308)uu_{x} + (0.293981)u^2u_{x}
# ====================================================================================================
# SNR =  300
# Dataset is using device:  cuda
#  19975  MSE: 1.11e-04  Reg: 9.72e-06  L1: 1.40e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.099684)u_{xx} + (-0.982314)uu_{x}
# ====================================================================================================
# SNR =  200
# Dataset is using device:  cuda
#  11825  MSE: 1.64e-04  Reg: 5.57e-06  L1: 1.43e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.099243)u_{xx} + (-0.996608)uu_{x}
# ====================================================================================================
# SNR =  100
# Dataset is using device:  cuda
#  19975  MSE: 3.35e-04  Reg: 1.01e-05  L1: 1.75e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.095886)u_{xx} + (-1.127864)uu_{x} + (0.278088)u^2u_{x}
# ====================================================================================================
# SNR =  90
# Dataset is using device:  cuda
#  10575  MSE: 3.51e-04  Reg: 1.38e-05  L1: 1.49e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.098082)u_{xx} + (-0.982420)uu_{x}
# ====================================================================================================
# SNR =  80
# Dataset is using device:  cuda
#   7100  MSE: 4.00e-04  Reg: 8.14e-06  L1: 1.43e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.097421)u_{xx} + (-0.991623)uu_{x}
# ====================================================================================================
# SNR =  70
# Dataset is using device:  cuda
#   6600  MSE: 4.87e-04  Reg: 5.84e-06  L1: 1.44e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.097163)u_{xx} + (-0.995792)uu_{x}
# ====================================================================================================
# SNR =  60
# Dataset is using device:  cuda
#  19975  MSE: 5.39e-04  Reg: 8.01e-06  L1: 1.74e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.100496)u_{xx} + (-0.971442)uu_{x}
# ====================================================================================================
# SNR =  50
# Dataset is using device:  cuda
#  13900  MSE: 6.45e-04  Reg: 9.06e-06  L1: 1.43e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.098560)u_{xx} + (-0.998170)uu_{x}
# ====================================================================================================
# SNR =  40
# Dataset is using device:  cuda
#   7800  MSE: 8.30e-04  Reg: 1.10e-05  L1: 1.45e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.093702)u_{xx} + (-0.995335)uu_{x}
# ====================================================================================================
# SNR =  30
# Dataset is using device:  cuda
#  18775  MSE: 1.09e-03  Reg: 1.54e-05  L1: 1.44e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.099750)u_{xx} + (-0.977122)uu_{x}
# ====================================================================================================
# SNR =  20
# Dataset is using device:  cuda
#  10375  MSE: 1.62e-03  Reg: 2.02e-05  L1: 1.43e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.094323)u_{xx} + (-0.978808)uu_{x}
# ====================================================================================================
# SNR =  10
# Dataset is using device:  cuda
#  12325  MSE: 3.32e-03  Reg: 1.58e-05  L1: 1.47e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.097376)u_{xx} + (-1.003542)uu_{x}
# ====================================================================================================
# SNR =  8
# Dataset is using device:  cuda
#  17075  MSE: 4.04e-03  Reg: 1.92e-05  L1: 1.44e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.099772)u_{xx} + (-0.979445)uu_{x}
# ====================================================================================================
# SNR =  6
# Dataset is using device:  cuda
#  19775  MSE: 5.37e-03  Reg: 3.22e-05  L1: 1.41e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.098343)u_{xx} + (-0.993376)uu_{x}
# ====================================================================================================
# SNR =  5
# Dataset is using device:  cuda
#  12950  MSE: 6.35e-03  Reg: 2.19e-05  L1: 1.38e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.093712)u_{xx} + (-0.978569)uu_{x}
# ====================================================================================================
# SNR =  4
# Dataset is using device:  cuda
#  18150  MSE: 8.27e-03  Reg: 2.78e-05  L1: 1.39e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.097523)u_{xx} + (-0.992262)uu_{x}
# ====================================================================================================
# SNR =  3
# Dataset is using device:  cuda
#  19975  MSE: 1.08e-02  Reg: 4.15e-05  L1: 1.74e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.125575)u_{xx} + (-1.077131)uu_{x} + (-0.054253)u^2u_{xxx}
# ====================================================================================================
# SNR =  2
# Dataset is using device:  cuda
#  12525  MSE: 1.53e-02  Reg: 4.77e-05  L1: 1.40e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.096907)u_{xx} + (-0.965380)uu_{x}
# ====================================================================================================
# SNR =  1
# Dataset is using device:  cuda
#  19975  MSE: 3.17e-02  Reg: 1.02e-04  L1: 1.65e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.014230)u_{x} + (0.106043)u_{xx} + (-0.925656)uu_{x} + (-0.072994)u^2u_{xx}
# ====================================================================================================
# SNR =  0.9
# Dataset is using device:  cuda
#  19975  MSE: 3.65e-02  Reg: 1.97e-04  L1: 2.64e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.192496)u_{x} + (0.032096)u_{xx} + (0.144524)u + (-0.370586)uu_{x} + (-0.412493)u^2 + (-0.061231)u^2u_{xx}
# ====================================================================================================
# SNR =  0.8
# Dataset is using device:  cuda
#  10975  MSE: 4.18e-02  Reg: 1.71e-04  L1: 1.56e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.086968)u_{xx} + (-0.897233)uu_{x} + (-0.045495)u^2 + (-0.043716)u^2u_{xx}
# ====================================================================================================
# SNR =  0.75
# Dataset is using device:  cuda
#   5050  MSE: 4.43e-02  Reg: 9.48e-05  L1: 1.55e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.069408)u_{x} + (0.080774)u_{xx} + (-0.744404)uu_{x} + (-0.036341)u^2u_{xx}
# ====================================================================================================
# SNR =  0.7
# Dataset is using device:  cuda
#  19975  MSE: 4.52e-02  Reg: 2.31e-04  L1: 2.14e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (0.065961)u_{xx} + (-0.948334)uu_{x} + (0.171231)uu_{xx} + (-0.223440)u^2u_{x} + (-0.159945)u^2u_{xx}
# ====================================================================================================
# SNR =  0.6
# Dataset is using device:  cuda
#  19975  MSE: 5.16e-02  Reg: 2.82e-04  L1: 7.92e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.350738)u_{x} + (0.115141)u_{xx} + (0.036720)u_{xxx} + (0.153557)u + (1.238451)uu_{x} + (-0.604835)uu_{xx} + (-0.056207)uu_{xxx} + (-0.714502)u^2 + (-1.249835)u^2u_{x} + (0.073818)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.5
# Dataset is using device:  cuda
#  19975  MSE: 6.42e-02  Reg: 4.47e-04  L1: 1.82e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.296792)u_{x} + (0.131415)u + (-0.383776)u^2 + (-0.353585)u^2u_{x}
# ====================================================================================================
# SNR =  0.4
# Dataset is using device:  cuda
#  10600  MSE: 8.17e-02  Reg: 3.12e-04  L1: 2.12e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.173342)u_{x} + (0.035873)u_{xx} + (0.106000)u + (-0.510948)uu_{x} + (-0.008481)uu_{xxx} + (-0.302067)u^2
# ====================================================================================================
# SNR =  0.3
# Dataset is using device:  cuda
#  18975  MSE: 1.09e-01  Reg: 6.22e-04  L1: 2.98e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.233968)u_{x} + (0.144395)u + (-0.404840)uu_{x} + (0.152400)uu_{xx} + (-0.349837)u^2 + (-0.141221)u^2u_{xx}
# ====================================================================================================
# SNR =  0.25
# Dataset is using device:  cuda
#  19975  MSE: 1.28e-01  Reg: 7.87e-04  L1: 3.64e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.261320)u_{x} + (0.014917)u_{xx} + (0.002303)u_{xxx} + (0.135286)u + (0.062052)uu_{xx} + (-0.425008)u^2 + (-0.135184)u^2u_{xx}
# ====================================================================================================
# SNR =  0.2
# Dataset is using device:  cuda
#  19975  MSE: 1.61e-01  Reg: 1.16e-03  L1: 5.61e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.460205)u_{x} + (0.003481)u_{xxx} + (0.147216)u + (1.379280)uu_{x} + (-0.041881)uu_{xx} + (0.033115)uu_{xxx} + (-0.463744)u^2 + (-2.368657)u^2u_{x} + (-0.118220)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.1
# Dataset is using device:  cuda
#  15900  MSE: 3.25e-01  Reg: 1.84e-03  L1: 1.99e+00 Algorithm converged. Writing model to disk.
#
# Predicted PDE:  u_t = (-0.214852)u_{x} + (-0.002757)u_{xxx} + (-0.189485)uu_{x} + (0.029550)uu_{xx} + (-0.130209)u^2 + (-0.252210)u^2u_{x} + (-0.031092)u^2u_{xx}
#          SNR          u_{x}    u_{xx}   u_{xxx}         u       u^2    uu_{x}
# 0   No noise  0.0  0.000000  0.098428  0.000000  0.000000  0.000000 -0.992248  \
# 1      20000  0.0  0.000000  0.099912  0.000000  0.000000  0.000000 -0.991904
# 2      15000  0.0  0.000000  0.098517  0.000000  0.000000  0.000000 -0.995592
# 3      10000  0.0  0.000000  0.099015  0.000000  0.000000  0.000000 -0.995755
# 4       7500  0.0  0.000000  0.099128  0.000000  0.000000  0.000000 -0.993309
# 5       5000  0.0  0.000000  0.099237  0.000000  0.000000  0.000000 -0.988658
# 6       3000  0.0  0.000000  0.098146  0.000000  0.000000  0.000000 -0.989801
# 7       2000  0.0  0.000000  0.098584  0.000000  0.000000  0.000000 -0.987220
# 8       1000  0.0  0.000000  0.100100  0.000000  0.000000  0.000000 -0.984485
# 9        800  0.0  0.000000  0.098812  0.000000  0.000000  0.000000 -0.986109
# 10       500  0.0  0.000000  0.097645  0.000000  0.000000  0.000000 -1.130308
# 11       300  0.0  0.000000  0.099684  0.000000  0.000000  0.000000 -0.982314
# 12       200  0.0  0.000000  0.099243  0.000000  0.000000  0.000000 -0.996608
# 13       100  0.0  0.000000  0.095886  0.000000  0.000000  0.000000 -1.127864
# 14        90  0.0  0.000000  0.098082  0.000000  0.000000  0.000000 -0.982420
# 15        80  0.0  0.000000  0.097421  0.000000  0.000000  0.000000 -0.991623
# 16        70  0.0  0.000000  0.097163  0.000000  0.000000  0.000000 -0.995792
# 17        60  0.0  0.000000  0.100496  0.000000  0.000000  0.000000 -0.971442
# 18        50  0.0  0.000000  0.098560  0.000000  0.000000  0.000000 -0.998170
# 19        40  0.0  0.000000  0.093702  0.000000  0.000000  0.000000 -0.995335
# 20        30  0.0  0.000000  0.099750  0.000000  0.000000  0.000000 -0.977122
# 21        20  0.0  0.000000  0.094323  0.000000  0.000000  0.000000 -0.978808
# 22        10  0.0  0.000000  0.097376  0.000000  0.000000  0.000000 -1.003542
# 23         8  0.0  0.000000  0.099772  0.000000  0.000000  0.000000 -0.979445
# 24         6  0.0  0.000000  0.098343  0.000000  0.000000  0.000000 -0.993376
# 25         5  0.0  0.000000  0.093712  0.000000  0.000000  0.000000 -0.978569
# 26         4  0.0  0.000000  0.097523  0.000000  0.000000  0.000000 -0.992262
# 27         3  0.0  0.000000  0.125575  0.000000  0.000000  0.000000 -1.077131
# 28         2  0.0  0.000000  0.096907  0.000000  0.000000  0.000000 -0.965380
# 29         1  0.0 -0.014230  0.106043  0.000000  0.000000  0.000000 -0.925656
# 30       0.9  0.0 -0.192496  0.032096  0.000000  0.144524 -0.412493 -0.370586
# 31       0.8  0.0  0.000000  0.086968  0.000000  0.000000 -0.045495 -0.897233
# 32      0.75  0.0 -0.069408  0.080774  0.000000  0.000000  0.000000 -0.744404
# 33       0.7  0.0  0.000000  0.065961  0.000000  0.000000  0.000000 -0.948334
# 34       0.6  0.0 -0.350738  0.115141  0.036720  0.153557 -0.714502  1.238451
# 35       0.5  0.0 -0.296792  0.000000  0.000000  0.131415 -0.383776  0.000000
# 36       0.4  0.0 -0.173342  0.035873  0.000000  0.106000 -0.302067 -0.510948
# 37       0.3  0.0 -0.233968  0.000000  0.000000  0.144395 -0.349837 -0.404840
# 38      0.25  0.0 -0.261320  0.014917  0.002303  0.135286 -0.425008  0.000000
# 39       0.2  0.0 -0.460205  0.000000  0.003481  0.147216 -0.463744  1.379280
# 40       0.1  0.0 -0.214852  0.000000 -0.002757  0.000000 -0.130209 -0.189485
#
#     u^2u_{x}   uu_{xx}  u^2u_{xx}  uu_{xxx}  u^2u_{xxx}
# 0   0.000000  0.000000   0.000000  0.000000    0.000000
# 1   0.000000  0.000000   0.000000  0.000000    0.000000
# 2   0.000000  0.000000   0.000000  0.000000    0.000000
# 3   0.000000  0.000000   0.000000  0.000000    0.000000
# 4   0.000000  0.000000   0.000000  0.000000    0.000000
# 5   0.000000  0.000000   0.000000  0.000000    0.000000
# 6   0.000000  0.000000   0.000000  0.000000    0.000000
# 7   0.000000  0.000000   0.000000  0.000000    0.000000
# 8   0.000000  0.000000   0.000000  0.000000    0.000000
# 9   0.000000  0.000000   0.000000  0.000000    0.000000
# 10  0.293981  0.000000   0.000000  0.000000    0.000000
# 11  0.000000  0.000000   0.000000  0.000000    0.000000
# 12  0.000000  0.000000   0.000000  0.000000    0.000000
# 13  0.278088  0.000000   0.000000  0.000000    0.000000
# 14  0.000000  0.000000   0.000000  0.000000    0.000000
# 15  0.000000  0.000000   0.000000  0.000000    0.000000
# 16  0.000000  0.000000   0.000000  0.000000    0.000000
# 17  0.000000  0.000000   0.000000  0.000000    0.000000
# 18  0.000000  0.000000   0.000000  0.000000    0.000000
# 19  0.000000  0.000000   0.000000  0.000000    0.000000
# 20  0.000000  0.000000   0.000000  0.000000    0.000000
# 21  0.000000  0.000000   0.000000  0.000000    0.000000
# 22  0.000000  0.000000   0.000000  0.000000    0.000000
# 23  0.000000  0.000000   0.000000  0.000000    0.000000
# 24  0.000000  0.000000   0.000000  0.000000    0.000000
# 25  0.000000  0.000000   0.000000  0.000000    0.000000
# 26  0.000000  0.000000   0.000000  0.000000    0.000000
# 27  0.000000  0.000000   0.000000  0.000000   -0.054253
# 28  0.000000  0.000000   0.000000  0.000000    0.000000
# 29  0.000000  0.000000  -0.072994  0.000000    0.000000
# 30  0.000000  0.000000  -0.061231  0.000000    0.000000
# 31  0.000000  0.000000  -0.043716  0.000000    0.000000
# 32  0.000000  0.000000  -0.036341  0.000000    0.000000
# 33 -0.223440  0.171231  -0.159945  0.000000    0.000000
# 34 -1.249835 -0.604835   0.000000 -0.056207    0.073818
# 35 -0.353585  0.000000   0.000000  0.000000    0.000000
# 36  0.000000  0.000000   0.000000 -0.008481    0.000000
# 37  0.000000  0.152400  -0.141221  0.000000    0.000000
# 38  0.000000  0.062052  -0.135184  0.000000    0.000000
# 39 -2.368657 -0.041881   0.000000  0.033115   -0.118220
# 40 -0.252210  0.029550  -0.031092  0.000000    0.000000

# %%
descr
# Out:
# ['',
#  'u_{x}',
#  'u_{xx}',
#  'u_{xxx}',
#  'u',
#  'uu_{x}',
#  'uu_{xx}',
#  'uu_{xxx}',
#  'u^2',
#  'u^2u_{x}',
#  'u^2u_{xx}',
#  'u^2u_{xxx}']
