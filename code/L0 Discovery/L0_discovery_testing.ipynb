# %%
from L0_discovery import *
data_path = "../../datasets"
results_path = "../L0 Discovery"
import pandas as pd

# %%
# Simple PDE ut = 0.8ux

pred_coefficients=[]

snrs = ["No noise",20000,15000,10000,7500,5000,3000,2000,1000,800,500,300,200,100,90,80,70,60,50,40,30,20,10,8,6,5,4,3,2,1,0.9,0.8,0.75,0.7,0.6,0.5,0.4,0.3,0.25,0.2,0.1]

for j in range(len(snrs)):
    print("="*100)
    print("SNR = ",snrs[j])

    # Loading u,x,t
    path = data_path+"/4_"+str(j)+".pkl"
    sols,descr = discover_pde(path)
    print("\nPDEs Predicted by L0: ")
    for i in range(len(sols)):
        print(return_pde(sols[i]["B"], descr))
    
    # Desired PDE
    w= sols[0]["B"]
    print("\nDesired PDE: ", return_pde(w, descr))
    pred_coefficients.append([snrs[j]]+list(w))
    
df_4 = pd.DataFrame(pred_coefficients, columns = ["SNR"]+descr )
df_4.to_csv(results_path+"/simplepde_results.csv")
# Out:
# ====================================================================================================
# SNR =  No noise
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  4
# Iteration: 4. Number of non-zeros:  10
#
# PDEs Predicted by L0:
# u_t = (-0.790575)u_{x}
# u_t = (-0.790965)u_{x} + (0.358622)u_{xx}
# u_t = (-0.682168)u_{x} + (0.353659)u_{xx} + (0.525332)u_{xxx} + (-0.195599)uu_{x}
# u_t = (-0.000342) + (-0.647554)u_{x} + (0.346817)u_{xx} + (0.284073)u_{xxx} + (0.002287)u^2 + (-0.429698)uu_{x} + (0.317865)u^2u_{x} + (0.143320)uu_{xx} + (1.601706)uu_{xxx} + (-2.030178)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.790575)u_{x}
# ====================================================================================================
# SNR =  20000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  4
# Iteration: 4. Number of non-zeros:  10
#
# PDEs Predicted by L0:
# u_t = (-0.790372)u_{x}
# u_t = (-0.790761)u_{x} + (0.357892)u_{xx}
# u_t = (-0.682836)u_{x} + (0.353027)u_{xx} + (0.502268)u_{xxx} + (-0.195738)uu_{x}
# u_t = (-0.000341) + (-0.647593)u_{x} + (0.346283)u_{xx} + (0.261359)u_{xxx} + (0.002270)u^2 + (-0.434692)uu_{x} + (0.324419)u^2u_{x} + (0.141932)uu_{xx} + (1.592456)uu_{xxx} + (-2.015549)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.790372)u_{x}
# ====================================================================================================
# SNR =  15000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  4
# Iteration: 4. Number of non-zeros:  10
#
# PDEs Predicted by L0:
# u_t = (-0.790285)u_{x}
# u_t = (-0.790667)u_{x} + (0.357463)u_{xx}
# u_t = (-0.682868)u_{x} + (0.352613)u_{xx} + (0.493541)u_{xxx} + (-0.196370)uu_{x}
# u_t = (-0.000338) + (-0.647527)u_{x} + (0.346033)u_{xx} + (0.243820)u_{xxx} + (0.002259)u^2 + (-0.435985)uu_{x} + (0.325502)u^2u_{x} + (0.141184)uu_{xx} + (1.625779)uu_{xxx} + (-2.039664)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.790285)u_{x}
# ====================================================================================================
# SNR =  10000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  4
# Iteration: 4. Number of non-zeros:  10
#
# PDEs Predicted by L0:
# u_t = (-0.790127)u_{x}
# u_t = (-0.790516)u_{x} + (0.356882)u_{xx}
# u_t = (-0.682797)u_{x} + (0.352055)u_{xx} + (0.477686)u_{xxx} + (-0.197652)uu_{x}
# u_t = (-0.000331) + (-0.647417)u_{x} + (0.342897)u_{xx} + (0.225193)u_{xxx} + (0.002268)u^2 + (-0.438445)uu_{x} + (0.327235)u^2u_{x} + (0.147230)uu_{xx} + (1.605483)uu_{xxx} + (-1.992399)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.790127)u_{x}
# ====================================================================================================
# SNR =  7500
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  4
# Iteration: 4. Number of non-zeros:  10
#
# PDEs Predicted by L0:
# u_t = (-0.789998)u_{x}
# u_t = (-0.790392)u_{x} + (0.357446)u_{xx}
# u_t = (-0.683541)u_{x} + (0.352722)u_{xx} + (0.453863)u_{xxx} + (-0.198045)uu_{x}
# u_t = (-0.000327) + (-0.647589)u_{x} + (0.348004)u_{xx} + (0.199191)u_{xxx} + (0.002175)u^2 + (-0.442818)uu_{x} + (0.332627)u^2u_{x} + (0.132126)uu_{xx} + (1.617634)uu_{xxx} + (-2.003358)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.789998)u_{x}
# ====================================================================================================
# SNR =  5000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.789668)u_{x}
# u_t = (-0.790056)u_{x} + (0.355207)u_{xx}
# u_t = (-0.651167)u_{x} + (0.351466)u_{xx} + (0.362303)u_{xxx} + (-0.458762)uu_{x} + (0.353367)u^2u_{x}
#
# Desired PDE:  u_t = (-0.789668)u_{x}
# ====================================================================================================
# SNR =  3000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.789025)u_{x}
# u_t = (-0.789414)u_{x} + (0.356745)u_{xx}
# u_t = (-0.650572)u_{x} + (0.353294)u_{xx} + (0.310369)u_{xxx} + (-0.469411)uu_{x} + (0.364370)u^2u_{x}
#
# Desired PDE:  u_t = (-0.789025)u_{x}
# ====================================================================================================
# SNR =  2000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  2
# Iteration: 5. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.788355)u_{x}
# u_t = (-0.788360)u_{x}
# u_t = (-0.788360)u_{x}
# u_t = (-0.788753)u_{x} + (0.354550)u_{xx}
# u_t = (-0.650672)u_{x} + (0.351204)u_{xx} + (0.234713)u_{xxx} + (-0.483849)uu_{x} + (0.381425)u^2u_{x}
#
# Desired PDE:  u_t = (-0.788355)u_{x}
# ====================================================================================================
# SNR =  1000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.785718)u_{x}
# u_t = (-0.786088)u_{x} + (0.352986)u_{xx}
# u_t = (-0.649780)u_{x} + (0.356423)u_{xx} + (0.000233)u + (-0.529319)uu_{x} + (0.430991)u^2u_{x}
#
# Desired PDE:  u_t = (-0.785718)u_{x}
# ====================================================================================================
# SNR =  800
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.784359)u_{x}
# u_t = (-0.784745)u_{x} + (0.345687)u_{xx}
# u_t = (-0.647439)u_{x} + (0.353860)u_{xx} + (0.000473)u^2 + (-0.537681)uu_{x} + (0.437502)u^2u_{x} + (-0.122169)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.784359)u_{x}
# ====================================================================================================
# SNR =  500
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.780808)u_{x}
# u_t = (-0.781188)u_{x} + (0.342932)u_{xx}
# u_t = (-0.650297)u_{x} + (0.351722)u_{xx} + (-0.229709)u_{xxx} + (0.000449)u^2 + (-0.568047)uu_{x} + (0.480864)u^2u_{x}
#
# Desired PDE:  u_t = (-0.780808)u_{x}
# ====================================================================================================
# SNR =  300
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  2
# Iteration: 10. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.774122)u_{x}
# u_t = (-0.774127)u_{x}
# u_t = (-0.774127)u_{x}
# u_t = (-0.774127)u_{x}
# u_t = (-0.774127)u_{x}
# u_t = (-0.774127)u_{x}
# u_t = (-0.774127)u_{x}
# u_t = (-0.774127)u_{x}
# u_t = (-0.774513)u_{x} + (0.341527)u_{xx}
# u_t = (-0.646222)u_{x} + (0.340826)u_{xx} + (-0.499163)u_{xxx} + (-0.629592)uu_{x} + (0.547430)u^2u_{x}
#
# Desired PDE:  u_t = (-0.774122)u_{x}
# ====================================================================================================
# SNR =  200
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  3
# Iteration: 3. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (-0.767304)u_{x}
# u_t = (-0.802211)u_{x} + (0.322362)u_{xx} + (-0.625036)u_{xxx}
# u_t = (-0.643951)u_{x} + (0.296548)u_{xx} + (-0.753945)u_{xxx} + (-0.674653)uu_{x} + (0.609076)u^2u_{x} + (0.053312)uu_{xx} + (0.233878)uu_{xxx}
#
# Desired PDE:  u_t = (-0.767304)u_{x}
# ====================================================================================================
# SNR =  100
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  2
# Iteration: 4. Number of non-zeros:  2
# Iteration: 5. Number of non-zeros:  2
# Iteration: 6. Number of non-zeros:  2
# Iteration: 7. Number of non-zeros:  2
# Iteration: 8. Number of non-zeros:  2
# Iteration: 9. Number of non-zeros:  2
# Iteration: 10. Number of non-zeros:  2
# Iteration: 11. Number of non-zeros:  4
# Iteration: 12. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.745734)u_{x}
# u_t = (-0.809949)u_{x} + (-0.980552)u_{xxx}
# u_t = (-0.809949)u_{x} + (-0.980552)u_{xxx}
# u_t = (-0.809949)u_{x} + (-0.980552)u_{xxx}
# u_t = (-0.809949)u_{x} + (-0.980552)u_{xxx}
# u_t = (-0.809949)u_{x} + (-0.980552)u_{xxx}
# u_t = (-0.809949)u_{x} + (-0.980552)u_{xxx}
# u_t = (-0.809949)u_{x} + (-0.980552)u_{xxx}
# u_t = (-0.809949)u_{x} + (-0.980552)u_{xxx}
# u_t = (-0.809949)u_{x} + (-0.980552)u_{xxx}
# u_t = (-0.704261)u_{x} + (0.297192)u_{xx} + (-0.973141)u_{xxx} + (-0.243285)uu_{x}
# u_t = (-0.639988)u_{x} + (0.256100)u_{xx} + (-0.983533)u_{xxx} + (-0.724691)uu_{x} + (0.652469)u^2u_{x} + (0.100376)uu_{xx}
#
# Desired PDE:  u_t = (-0.745734)u_{x}
# ====================================================================================================
# SNR =  90
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  2
# Iteration: 4. Number of non-zeros:  2
# Iteration: 5. Number of non-zeros:  2
# Iteration: 6. Number of non-zeros:  2
# Iteration: 7. Number of non-zeros:  2
# Iteration: 8. Number of non-zeros:  2
# Iteration: 9. Number of non-zeros:  2
# Iteration: 10. Number of non-zeros:  2
# Iteration: 11. Number of non-zeros:  4
# Iteration: 12. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (-0.737153)u_{x}
# u_t = (-0.807733)u_{x} + (-1.030606)u_{xxx}
# u_t = (-0.807733)u_{x} + (-1.030606)u_{xxx}
# u_t = (-0.807733)u_{x} + (-1.030606)u_{xxx}
# u_t = (-0.807733)u_{x} + (-1.030606)u_{xxx}
# u_t = (-0.807733)u_{x} + (-1.030606)u_{xxx}
# u_t = (-0.807733)u_{x} + (-1.030606)u_{xxx}
# u_t = (-0.807733)u_{x} + (-1.030606)u_{xxx}
# u_t = (-0.807733)u_{x} + (-1.030606)u_{xxx}
# u_t = (-0.807733)u_{x} + (-1.030606)u_{xxx}
# u_t = (-0.698782)u_{x} + (0.286084)u_{xx} + (-1.019573)u_{xxx} + (-0.249916)uu_{x}
# u_t = (0.000163) + (-0.633336)u_{x} + (0.228758)u_{xx} + (-1.028185)u_{xxx} + (-0.741076)uu_{x} + (0.665779)u^2u_{x} + (0.133692)uu_{xx}
#
# Desired PDE:  u_t = (-0.737153)u_{x}
# ====================================================================================================
# SNR =  80
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  2
# Iteration: 4. Number of non-zeros:  2
# Iteration: 5. Number of non-zeros:  2
# Iteration: 6. Number of non-zeros:  2
# Iteration: 7. Number of non-zeros:  2
# Iteration: 8. Number of non-zeros:  2
# Iteration: 9. Number of non-zeros:  2
# Iteration: 10. Number of non-zeros:  3
# Iteration: 11. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (-0.735909)u_{x}
# u_t = (-0.809132)u_{x} + (-1.040387)u_{xxx}
# u_t = (-0.809132)u_{x} + (-1.040387)u_{xxx}
# u_t = (-0.809132)u_{x} + (-1.040387)u_{xxx}
# u_t = (-0.809132)u_{x} + (-1.040387)u_{xxx}
# u_t = (-0.809132)u_{x} + (-1.040387)u_{xxx}
# u_t = (-0.809132)u_{x} + (-1.040387)u_{xxx}
# u_t = (-0.809132)u_{x} + (-1.040387)u_{xxx}
# u_t = (-0.809132)u_{x} + (-1.040387)u_{xxx}
# u_t = (-0.809504)u_{x} + (0.291477)u_{xx} + (-1.042305)u_{xxx}
# u_t = (-0.634889)u_{x} + (0.255489)u_{xx} + (-0.944027)u_{xxx} + (-0.763467)uu_{x} + (0.711408)u^2u_{x} + (0.075125)uu_{xx} + (-0.425264)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.735909)u_{x}
# ====================================================================================================
# SNR =  70
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  2
# Iteration: 4. Number of non-zeros:  2
# Iteration: 5. Number of non-zeros:  2
# Iteration: 6. Number of non-zeros:  2
# Iteration: 7. Number of non-zeros:  2
# Iteration: 8. Number of non-zeros:  2
# Iteration: 9. Number of non-zeros:  2
# Iteration: 10. Number of non-zeros:  2
# Iteration: 11. Number of non-zeros:  2
# Iteration: 12. Number of non-zeros:  2
# Iteration: 13. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.724561)u_{x}
# u_t = (-0.809131)u_{x} + (-1.127607)u_{xxx}
# u_t = (-0.809131)u_{x} + (-1.127607)u_{xxx}
# u_t = (-0.809131)u_{x} + (-1.127607)u_{xxx}
# u_t = (-0.809131)u_{x} + (-1.127607)u_{xxx}
# u_t = (-0.809131)u_{x} + (-1.127607)u_{xxx}
# u_t = (-0.809131)u_{x} + (-1.127607)u_{xxx}
# u_t = (-0.809131)u_{x} + (-1.127607)u_{xxx}
# u_t = (-0.809131)u_{x} + (-1.127607)u_{xxx}
# u_t = (-0.809131)u_{x} + (-1.127607)u_{xxx}
# u_t = (-0.809131)u_{x} + (-1.127607)u_{xxx}
# u_t = (-0.809131)u_{x} + (-1.127607)u_{xxx}
# u_t = (-0.646381)u_{x} + (0.239712)u_{xx} + (-1.116602)u_{xxx} + (-0.712862)uu_{x} + (0.662151)u^2u_{x} + (0.079617)uu_{xx}
#
# Desired PDE:  u_t = (-0.724561)u_{x}
# ====================================================================================================
# SNR =  60
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  2
# Iteration: 4. Number of non-zeros:  2
# Iteration: 5. Number of non-zeros:  2
# Iteration: 6. Number of non-zeros:  2
# Iteration: 7. Number of non-zeros:  2
# Iteration: 8. Number of non-zeros:  2
# Iteration: 9. Number of non-zeros:  2
# Iteration: 10. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.718711)u_{x}
# u_t = (-0.806235)u_{x} + (-1.099769)u_{xxx}
# u_t = (-0.806235)u_{x} + (-1.099769)u_{xxx}
# u_t = (-0.806235)u_{x} + (-1.099769)u_{xxx}
# u_t = (-0.806235)u_{x} + (-1.099769)u_{xxx}
# u_t = (-0.806235)u_{x} + (-1.099769)u_{xxx}
# u_t = (-0.806235)u_{x} + (-1.099769)u_{xxx}
# u_t = (-0.806235)u_{x} + (-1.099769)u_{xxx}
# u_t = (-0.806235)u_{x} + (-1.099769)u_{xxx}
# u_t = (-0.626710)u_{x} + (0.232977)u_{xx} + (-1.079640)u_{xxx} + (-0.781406)uu_{x} + (0.722225)u^2u_{x} + (0.077831)uu_{xx}
#
# Desired PDE:  u_t = (-0.718711)u_{x}
# ====================================================================================================
# SNR =  50
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  2
# Iteration: 4. Number of non-zeros:  2
# Iteration: 5. Number of non-zeros:  2
# Iteration: 6. Number of non-zeros:  2
# Iteration: 7. Number of non-zeros:  2
# Iteration: 8. Number of non-zeros:  2
# Iteration: 9. Number of non-zeros:  2
# Iteration: 10. Number of non-zeros:  2
# Iteration: 11. Number of non-zeros:  2
# Iteration: 12. Number of non-zeros:  2
# Iteration: 13. Number of non-zeros:  2
# Iteration: 14. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (-0.708426)u_{x}
# u_t = (-0.806212)u_{x} + (-1.162007)u_{xxx}
# u_t = (-0.806212)u_{x} + (-1.162007)u_{xxx}
# u_t = (-0.806212)u_{x} + (-1.162007)u_{xxx}
# u_t = (-0.806212)u_{x} + (-1.162007)u_{xxx}
# u_t = (-0.806212)u_{x} + (-1.162007)u_{xxx}
# u_t = (-0.806212)u_{x} + (-1.162007)u_{xxx}
# u_t = (-0.806212)u_{x} + (-1.162007)u_{xxx}
# u_t = (-0.806212)u_{x} + (-1.162007)u_{xxx}
# u_t = (-0.806212)u_{x} + (-1.162007)u_{xxx}
# u_t = (-0.806212)u_{x} + (-1.162007)u_{xxx}
# u_t = (-0.806212)u_{x} + (-1.162007)u_{xxx}
# u_t = (-0.806212)u_{x} + (-1.162007)u_{xxx}
# u_t = (-0.626727)u_{x} + (0.201398)u_{xx} + (-1.087719)u_{xxx} + (-0.762999)uu_{x} + (0.686734)u^2u_{x} + (0.106860)uu_{xx} + (-0.242243)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.708426)u_{x}
# ====================================================================================================
# SNR =  40
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  2
# Iteration: 4. Number of non-zeros:  2
# Iteration: 5. Number of non-zeros:  2
# Iteration: 6. Number of non-zeros:  2
# Iteration: 7. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.687648)u_{x}
# u_t = (-0.802514)u_{x} + (-1.207619)u_{xxx}
# u_t = (-0.802514)u_{x} + (-1.207619)u_{xxx}
# u_t = (-0.802514)u_{x} + (-1.207619)u_{xxx}
# u_t = (-0.802514)u_{x} + (-1.207619)u_{xxx}
# u_t = (-0.802514)u_{x} + (-1.207619)u_{xxx}
# u_t = (-0.620010)u_{x} + (0.221037)u_{xx} + (-1.179959)u_{xxx} + (-0.000700)u^2 + (-0.784142)uu_{x} + (0.711059)u^2u_{x}
#
# Desired PDE:  u_t = (-0.687648)u_{x}
# ====================================================================================================
# SNR =  30
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  2
# Iteration: 8. Number of non-zeros:  2
# Iteration: 9. Number of non-zeros:  2
# Iteration: 10. Number of non-zeros:  2
# Iteration: 11. Number of non-zeros:  2
# Iteration: 12. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (-0.654333)u_{x}
# u_t = (-0.654333)u_{x}
# u_t = (-0.654333)u_{x}
# u_t = (-0.654333)u_{x}
# u_t = (-0.654333)u_{x}
# u_t = (-0.654333)u_{x}
# u_t = (-0.785200)u_{x} + (-1.276954)u_{xxx}
# u_t = (-0.798778)u_{x} + (-1.310994)u_{xxx}
# u_t = (-0.798778)u_{x} + (-1.310994)u_{xxx}
# u_t = (-0.798778)u_{x} + (-1.310994)u_{xxx}
# u_t = (-0.798778)u_{x} + (-1.310994)u_{xxx}
# u_t = (-0.603762)u_{x} + (0.191156)u_{xx} + (-1.237408)u_{xxx} + (-0.000867)u^2 + (-0.810985)uu_{x} + (0.705615)u^2u_{x} + (-0.152212)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.654333)u_{x}
# ====================================================================================================
# SNR =  20
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  3
# Iteration: 3. Number of non-zeros:  3
# Iteration: 4. Number of non-zeros:  3
# Iteration: 5. Number of non-zeros:  3
# Iteration: 6. Number of non-zeros:  3
# Iteration: 7. Number of non-zeros:  9
#
# PDEs Predicted by L0:
# u_t = (-0.601883)u_{x}
# u_t = (-0.722259)u_{x} + (-1.287308)u_{xxx} + (-0.173128)u^2u_{x}
# u_t = (-0.765393)u_{x} + (-1.337964)u_{xxx} + (-0.074506)u^2u_{x}
# u_t = (-0.765393)u_{x} + (-1.337964)u_{xxx} + (-0.074506)u^2u_{x}
# u_t = (-0.765393)u_{x} + (-1.337964)u_{xxx} + (-0.074506)u^2u_{x}
# u_t = (-0.765393)u_{x} + (-1.337964)u_{xxx} + (-0.074506)u^2u_{x}
# u_t = (0.000739) + (-0.592639)u_{x} + (0.123590)u_{xx} + (-1.127951)u_{xxx} + (-0.003415)u^2 + (-0.805118)uu_{x} + (0.704653)u^2u_{x} + (-0.464560)uu_{xxx} + (0.034415)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.601883)u_{x}
# ====================================================================================================
# SNR =  10
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  2
# Iteration: 4. Number of non-zeros:  2
# Iteration: 5. Number of non-zeros:  10
#
# PDEs Predicted by L0:
# u_t = (-0.486864)u_{x}
# u_t = (-0.584237)u_{x} + (-1.020402)u_{xxx}
# u_t = (-0.701085)u_{x} + (-1.270989)u_{xxx}
# u_t = (-0.741716)u_{x} + (-1.358125)u_{xxx}
# u_t = (0.000724) + (-0.546987)u_{x} + (0.069758)u_{xx} + (-1.095724)u_{xxx} + (-0.003490)u^2 + (-0.744370)uu_{x} + (0.540478)u^2u_{x} + (0.052626)u^2u_{xx} + (-0.605499)uu_{xxx} + (0.037177)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.486864)u_{x}
# ====================================================================================================
# SNR =  8
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  2
# Iteration: 4. Number of non-zeros:  2
# Iteration: 5. Number of non-zeros:  10
#
# PDEs Predicted by L0:
# u_t = (-0.464395)u_{x}
# u_t = (-0.557274)u_{x} + (-0.872051)u_{xxx}
# u_t = (-0.668729)u_{x} + (-1.107164)u_{xxx}
# u_t = (-0.717233)u_{x} + (-1.209483)u_{xxx}
# u_t = (0.000796) + (-0.552728)u_{x} + (0.020039)u_{xx} + (-1.023426)u_{xxx} + (-0.003448)u^2 + (-0.653741)uu_{x} + (0.501979)u^2u_{x} + (0.100073)uu_{xx} + (-0.004210)u^2u_{xx} + (-0.682676)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.464395)u_{x}
# ====================================================================================================
# SNR =  6
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  2
# Iteration: 4. Number of non-zeros:  2
# Iteration: 5. Number of non-zeros:  9
#
# PDEs Predicted by L0:
# u_t = (-0.392624)u_{x}
# u_t = (-0.471149)u_{x} + (-0.856851)u_{xxx}
# u_t = (-0.565379)u_{x} + (-1.052164)u_{xxx}
# u_t = (-0.678455)u_{x} + (-1.286540)u_{xxx}
# u_t = (0.000621) + (-0.531847)u_{x} + (0.055426)u_{xx} + (-0.991512)u_{xxx} + (-0.003155)u^2 + (-0.657711)uu_{x} + (0.433858)u^2u_{x} + (-0.953707)uu_{xxx} + (0.178733)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.392624)u_{x}
# ====================================================================================================
# SNR =  5
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  3
# Iteration: 4. Number of non-zeros:  3
# Iteration: 5. Number of non-zeros:  3
# Iteration: 6. Number of non-zeros:  9
#
# PDEs Predicted by L0:
# u_t = (-0.347955)u_{x}
# u_t = (-0.347955)u_{x}
# u_t = (-0.417546)u_{x} + (-0.996145)u_{xxx} + (-0.371540)uu_{x}
# u_t = (-0.501055)u_{x} + (-1.077503)u_{xxx} + (-0.260437)uu_{x}
# u_t = (-0.578968)u_{x} + (-1.153409)u_{xxx} + (-0.156779)uu_{x}
# u_t = (0.001084) + (-0.487026)u_{x} + (0.039698)u_{xx} + (-0.920544)u_{xxx} + (-0.002122)u + (-0.001371)u^2 + (-0.552579)uu_{x} + (0.310332)u^2u_{x} + (-0.574197)uu_{xxx}
#
# Desired PDE:  u_t = (-0.347955)u_{x}
# ====================================================================================================
# SNR =  4
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  3
# Iteration: 4. Number of non-zeros:  3
# Iteration: 5. Number of non-zeros:  3
# Iteration: 6. Number of non-zeros:  3
# Iteration: 7. Number of non-zeros:  3
# Iteration: 8. Number of non-zeros:  9
#
# PDEs Predicted by L0:
# u_t = (-0.311188)u_{x}
# u_t = (-0.311198)u_{x}
# u_t = (-0.373438)u_{x} + (-0.983470)u_{xxx} + (-0.382158)uu_{x}
# u_t = (-0.448126)u_{x} + (-1.060559)u_{xxx} + (-0.289509)uu_{x}
# u_t = (-0.537751)u_{x} + (-1.153065)u_{xxx} + (-0.178330)uu_{x}
# u_t = (-0.609389)u_{x} + (-1.227007)u_{xxx} + (-0.089463)uu_{x}
# u_t = (-0.609389)u_{x} + (-1.227007)u_{xxx} + (-0.089463)uu_{x}
# u_t = (0.000791) + (-0.498671)u_{x} + (0.032995)u_{xx} + (-0.941710)u_{xxx} + (-0.003600)u^2 + (-0.556683)uu_{x} + (0.343673)u^2u_{x} + (-0.762992)uu_{xxx} + (0.086329)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.311188)u_{x}
# ====================================================================================================
# SNR =  3
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  3
# Iteration: 3. Number of non-zeros:  3
# Iteration: 4. Number of non-zeros:  3
# Iteration: 5. Number of non-zeros:  3
# Iteration: 6. Number of non-zeros:  11
#
# PDEs Predicted by L0:
# u_t = (-0.271119)u_{x}
# u_t = (-0.325342)u_{x} + (-0.836062)u_{xxx} + (-0.394523)uu_{x}
# u_t = (-0.390411)u_{x} + (-0.909768)u_{xxx} + (-0.321860)uu_{x}
# u_t = (-0.468493)u_{x} + (-0.998216)u_{xxx} + (-0.234664)uu_{x}
# u_t = (-0.518205)u_{x} + (-1.054528)u_{xxx} + (-0.179150)uu_{x}
# u_t = (0.001235) + (-0.471550)u_{x} + (-0.001608)u_{xx} + (-0.957857)u_{xxx} + (-0.002836)u + (0.000027)u^2 + (-0.468390)uu_{x} + (0.302021)u^2u_{x} + (0.043737)u^2u_{xx} + (-0.386587)uu_{xxx} + (0.257690)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.271119)u_{x}
# ====================================================================================================
# SNR =  2
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  4
# Iteration: 5. Number of non-zeros:  4
# Iteration: 6. Number of non-zeros:  4
# Iteration: 7. Number of non-zeros:  4
# Iteration: 8. Number of non-zeros:  4
# Iteration: 9. Number of non-zeros:  4
# Iteration: 10. Number of non-zeros:  4
# Iteration: 11. Number of non-zeros:  4
# Iteration: 12. Number of non-zeros:  4
# Iteration: 13. Number of non-zeros:  4
# Iteration: 14. Number of non-zeros:  4
# Iteration: 15. Number of non-zeros:  4
# Iteration: 16. Number of non-zeros:  4
# Iteration: 17. Number of non-zeros:  4
# Iteration: 18. Number of non-zeros:  4
# Iteration: 19. Number of non-zeros:  4
# Iteration: 20. Number of non-zeros:  4
# Iteration: 21. Number of non-zeros:  4
# Iteration: 22. Number of non-zeros:  4
# Iteration: 23. Number of non-zeros:  4
# Iteration: 24. Number of non-zeros:  4
# Iteration: 25. Number of non-zeros:  4
# Iteration: 26. Number of non-zeros:  4
# Iteration: 27. Number of non-zeros:  10
#
# PDEs Predicted by L0:
# u_t = (-0.179031)u_{x}
# u_t = (-0.179031)u_{x}
# u_t = (-0.179031)u_{x}
# u_t = (-0.214838)u_{x} + (-0.351263)u_{xxx} + (-0.429168)uu_{x} + (-1.023152)uu_{xxx}
# u_t = (-0.257805)u_{x} + (-0.436632)u_{xxx} + (-0.493139)uu_{x} + (-1.150054)uu_{xxx}
# u_t = (-0.309366)u_{x} + (-0.531079)u_{xxx} + (-0.415018)uu_{x} + (-1.011415)uu_{xxx}
# u_t = (-0.371240)u_{x} + (-0.644416)u_{xxx} + (-0.321274)uu_{x} + (-0.845048)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (-0.409140)u_{x} + (-0.713841)u_{xxx} + (-0.263851)uu_{x} + (-0.743141)uu_{xxx}
# u_t = (0.000764) + (-0.408461)u_{x} + (-0.711673)u_{xxx} + (0.001287)u + (-0.005520)u^2 + (-0.327690)uu_{x} + (0.101946)u^2u_{x} + (0.034256)u^2u_{xx} + (-0.899670)uu_{xxx} + (0.244094)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.179031)u_{x}
# ====================================================================================================
# SNR =  1
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.106610)u_{x}
# u_t = (-0.106610)u_{x}
# u_t = (-0.106610)u_{x}
# u_t = (-0.106610)u_{x}
# u_t = (-0.106610)u_{x}
# u_t = (-0.106610)u_{x}
# u_t = (-0.106610)u_{x}
# u_t = (-0.106610)u_{x}
# u_t = (-0.106610)u_{x}
# u_t = (-0.106610)u_{x}
# u_t = (-0.106610)u_{x}
# u_t = (-0.127932)u_{x} + (-0.189684)u_{xxx} + (-0.244205)uu_{x} + (0.114680)u^2u_{xx} + (-0.427783)uu_{xxx} + (-0.179620)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.106610)u_{x}
# ====================================================================================================
# SNR =  0.9
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  4
# Iteration: 4. Number of non-zeros:  4
# Iteration: 5. Number of non-zeros:  4
# Iteration: 6. Number of non-zeros:  11
#
# PDEs Predicted by L0:
# u_t = (-0.085911)u_{x}
# u_t = (-0.085921)u_{x}
# u_t = (-0.103105)u_{x} + (-0.215398)u_{xxx} + (-0.194369)uu_{x} + (-0.367860)uu_{xxx}
# u_t = (-0.123726)u_{x} + (-0.255539)u_{xxx} + (-0.233243)uu_{x} + (-0.444770)uu_{xxx}
# u_t = (-0.148472)u_{x} + (-0.303708)u_{xxx} + (-0.279892)uu_{x} + (-0.537062)uu_{xxx}
# u_t = (0.000861) + (-0.178166)u_{x} + (-0.016345)u_{xx} + (-0.361931)u_{xxx} + (-0.009188)u + (0.010469)u^2 + (-0.335870)uu_{x} + (0.063400)u^2u_{x} + (0.054128)u^2u_{xx} + (-0.584959)uu_{xxx} + (0.042044)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.085911)u_{x}
# ====================================================================================================
# SNR =  0.8
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  3
# Iteration: 3. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.077164)u_{x}
# u_t = (-0.092596)u_{x} + (-0.209618)u_{xxx} + (-0.119101)uu_{x}
# u_t = (-0.111116)u_{x} + (-0.251541)u_{xxx} + (-0.205383)uu_{x} + (-0.098693)u^2u_{x} + (-0.466879)uu_{xxx}
#
# Desired PDE:  u_t = (-0.077164)u_{x}
# ====================================================================================================
# SNR =  0.75
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  4
# Iteration: 3. Number of non-zeros:  4
# Iteration: 4. Number of non-zeros:  4
# Iteration: 5. Number of non-zeros:  4
# Iteration: 6. Number of non-zeros:  4
# Iteration: 7. Number of non-zeros:  4
# Iteration: 8. Number of non-zeros:  4
# Iteration: 9. Number of non-zeros:  4
# Iteration: 10. Number of non-zeros:  4
# Iteration: 11. Number of non-zeros:  4
# Iteration: 12. Number of non-zeros:  4
# Iteration: 13. Number of non-zeros:  4
# Iteration: 14. Number of non-zeros:  4
# Iteration: 15. Number of non-zeros:  4
# Iteration: 16. Number of non-zeros:  4
# Iteration: 17. Number of non-zeros:  4
# Iteration: 18. Number of non-zeros:  11
#
# PDEs Predicted by L0:
# u_t = (-0.097208)u_{x}
# u_t = (-0.116650)u_{x} + (-0.158325)u_{xxx} + (-0.211304)uu_{x} + (-0.474939)uu_{xxx}
# u_t = (-0.139980)u_{x} + (-0.199228)u_{xxx} + (-0.253564)uu_{x} + (-0.569927)uu_{xxx}
# u_t = (-0.167976)u_{x} + (-0.237818)u_{xxx} + (-0.275575)uu_{x} + (-0.654797)uu_{xxx}
# u_t = (-0.201571)u_{x} + (-0.301297)u_{xxx} + (-0.236650)uu_{x} + (-0.582805)uu_{xxx}
# u_t = (-0.241886)u_{x} + (-0.377471)u_{xxx} + (-0.189940)uu_{x} + (-0.496415)uu_{xxx}
# u_t = (-0.250462)u_{x} + (-0.393675)u_{xxx} + (-0.180004)uu_{x} + (-0.478038)uu_{xxx}
# u_t = (-0.250462)u_{x} + (-0.393675)u_{xxx} + (-0.180004)uu_{x} + (-0.478038)uu_{xxx}
# u_t = (-0.250462)u_{x} + (-0.393675)u_{xxx} + (-0.180004)uu_{x} + (-0.478038)uu_{xxx}
# u_t = (-0.250462)u_{x} + (-0.393675)u_{xxx} + (-0.180004)uu_{x} + (-0.478038)uu_{xxx}
# u_t = (-0.250462)u_{x} + (-0.393675)u_{xxx} + (-0.180004)uu_{x} + (-0.478038)uu_{xxx}
# u_t = (-0.250462)u_{x} + (-0.393675)u_{xxx} + (-0.180004)uu_{x} + (-0.478038)uu_{xxx}
# u_t = (-0.250462)u_{x} + (-0.393675)u_{xxx} + (-0.180004)uu_{x} + (-0.478038)uu_{xxx}
# u_t = (-0.250462)u_{x} + (-0.393675)u_{xxx} + (-0.180004)uu_{x} + (-0.478038)uu_{xxx}
# u_t = (-0.250462)u_{x} + (-0.393675)u_{xxx} + (-0.180004)uu_{x} + (-0.478038)uu_{xxx}
# u_t = (-0.250462)u_{x} + (-0.393675)u_{xxx} + (-0.180004)uu_{x} + (-0.478038)uu_{xxx}
# u_t = (-0.250462)u_{x} + (-0.393675)u_{xxx} + (-0.180004)uu_{x} + (-0.478038)uu_{xxx}
# u_t = (-0.000036) + (-0.248902)u_{x} + (0.087958)u_{xx} + (-0.391168)u_{xxx} + (-0.002618)u + (-0.174783)uu_{x} + (-0.014017)u^2u_{x} + (-0.155162)uu_{xx} + (-0.075940)u^2u_{xx} + (-0.415102)uu_{xxx} + (-0.092825)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.097208)u_{x}
# ====================================================================================================
# SNR =  0.7
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  4
# Iteration: 4. Number of non-zeros:  4
# Iteration: 5. Number of non-zeros:  4
# Iteration: 6. Number of non-zeros:  11
#
# PDEs Predicted by L0:
# u_t = (-0.071452)u_{x}
# u_t = (-0.071469)u_{x}
# u_t = (-0.085763)u_{x} + (-0.192673)u_{xxx} + (-0.154910)uu_{x} + (-0.290509)u^2u_{xxx}
# u_t = (-0.102915)u_{x} + (-0.231208)u_{xxx} + (-0.185892)uu_{x} + (-0.346541)u^2u_{xxx}
# u_t = (-0.123498)u_{x} + (-0.277449)u_{xxx} + (-0.223071)uu_{x} + (-0.413779)u^2u_{xxx}
# u_t = (0.002392) + (-0.148198)u_{x} + (-0.049393)u_{xx} + (-0.326271)u_{xxx} + (-0.004922)u + (-0.000729)u^2 + (-0.267685)uu_{x} + (0.327923)uu_{xx} + (-0.280279)u^2u_{xx} + (-0.336101)uu_{xxx} + (-0.161511)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.071452)u_{x}
# ====================================================================================================
# SNR =  0.6
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.069472)u_{x}
# u_t = (-0.069489)u_{x}
# u_t = (-0.069489)u_{x}
# u_t = (-0.083386)u_{x} + (-0.184452)u_{xxx} + (-0.148423)uu_{x} + (-0.097372)u^2u_{x} + (-0.327516)uu_{xxx}
#
# Desired PDE:  u_t = (-0.069472)u_{x}
# ====================================================================================================
# SNR =  0.5
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.030693)u_{x}
# u_t = (-0.036832)u_{x} + (-0.081004)u_{xxx} + (-0.063434)uu_{x} + (-0.028274)u^2u_{x} + (-0.081631)u^2u_{xx} + (-0.139261)uu_{xxx}
#
# Desired PDE:  u_t = (-0.030693)u_{x}
# ====================================================================================================
# SNR =  0.4
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  4
# Iteration: 4. Number of non-zeros:  11
#
# PDEs Predicted by L0:
# u_t = (-0.043000)u_{x}
# u_t = (-0.043000)u_{x}
# u_t = (-0.051601)u_{x} + (-0.111697)u_{xxx} + (-0.083631)uu_{x} + (-0.178803)u^2u_{xxx}
# u_t = (0.000629) + (-0.061921)u_{x} + (0.007456)u_{xx} + (-0.119618)u_{xxx} + (0.002426)u + (-0.003553)u^2 + (-0.100357)uu_{x} + (-0.024364)u^2u_{x} + (0.021299)u^2u_{xx} + (-0.142157)uu_{xxx} + (-0.145883)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.043000)u_{x}
# ====================================================================================================
# SNR =  0.3
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.022401)u_{x}
# u_t = (-0.026881)u_{x} + (-0.058620)u_{xxx} + (-0.002531)u^2 + (-0.018516)uu_{x} + (-0.039279)u^2u_{x} + (-0.084282)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.022401)u_{x}
# ====================================================================================================
# SNR =  0.25
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  11
#
# PDEs Predicted by L0:
# u_t = (-0.043842)u_{x}
# u_t = (-0.043853)u_{x}
# u_t = (-0.043853)u_{x}
# u_t = (-0.043853)u_{x}
# u_t = (-0.043853)u_{x}
# u_t = (-0.002252) + (-0.052623)u_{x} + (-0.015031)u_{xx} + (-0.049115)u_{xxx} + (0.003995)u^2 + (-0.051673)uu_{x} + (-0.062311)u^2u_{x} + (-0.160776)uu_{xx} + (0.173009)u^2u_{xx} + (-0.139598)uu_{xxx} + (-0.126480)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.043842)u_{x}
# ====================================================================================================
# SNR =  0.2
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  11
#
# PDEs Predicted by L0:
# u_t = (0.077385)uu_{xxx}
# u_t = (0.077423)uu_{xxx}
# u_t = (0.077423)uu_{xxx}
# u_t = (0.077423)uu_{xxx}
# u_t = (0.077423)uu_{xxx}
# u_t = (0.077423)uu_{xxx}
# u_t = (-0.001368) + (-0.023873)u_{x} + (0.013475)u_{xx} + (-0.068174)u_{xxx} + (0.000290)u + (0.006586)uu_{x} + (-0.034917)u^2u_{x} + (-0.106618)uu_{xx} + (0.050851)u^2u_{xx} + (0.092907)uu_{xxx} + (-0.066783)u^2u_{xxx}
#
# Desired PDE:  u_t = (0.077385)uu_{xxx}
# ====================================================================================================
# SNR =  0.1
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.029260)u^2u_{xxx}
# u_t = (-0.004449)u^2 + (-0.026263)uu_{x} + (-0.040175)uu_{xx} + (-0.024298)u^2u_{xx} + (-0.035112)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.029260)u^2u_{xxx}

# %%
# Heat equation ut = 0.15uxx

pred_coefficients=[]

snrs = ["No noise",20000,15000,10000,7500,5000,3000,2000,1000,800,500,300,200,100,90,80,70,60,50,40,30,20,10,8,6,5,4,3,2,1,0.9,0.8,0.75,0.7,0.6,0.5,0.4,0.3,0.25,0.2,0.1]

for j in range(len(snrs)):
    print("="*100)
    print("SNR = ",snrs[j])

    # Loading u,x,t
    path = data_path+"/1_"+str(j)+".pkl"
    sols,descr = discover_pde(path)
    print("\nPDEs Predicted by L0: ")
    for i in range(len(sols)):
        print(return_pde(sols[i]["B"], descr))
    
    # Desired PDE
    w= sols[0]["B"]
    print("\nDesired PDE: ", return_pde(w, descr))
    pred_coefficients.append([snrs[j]]+list(w))
    
df_1 = pd.DataFrame(pred_coefficients, columns = ["SNR"]+descr )
df_1.to_csv(results_path+"/heateqn_results.csv")
# Out:
# ====================================================================================================
# SNR =  No noise
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  3
# Iteration: 3. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (0.150681)u_{xx}
# u_t = (0.087603) + (0.113205)u_{xx} + (0.000127)uu_{xx}
# u_t = (0.105175) + (0.111634)u_{xx} + (-0.000000)u^2 + (0.000154)uu_{xx} + (-0.000000)u^2u_{xx}
#
# Desired PDE:  u_t = (0.150681)u_{xx}
# ====================================================================================================
# SNR =  20000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (0.130937)u_{xx}
# u_t = (0.436583) + (0.109868)u_{xx} + (-0.000344)u + (-0.000003)u^2 + (0.000131)uu_{xx} + (-0.000000)u^2u_{xx}
#
# Desired PDE:  u_t = (0.130937)u_{xx}
# ====================================================================================================
# SNR =  15000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (0.125811)u_{xx}
# u_t = (0.510293) + (0.127168)u_{xx} + (-0.000432)u + (-0.000004)u^2 + (-0.000000)u^2u_{xx}
#
# Desired PDE:  u_t = (0.125811)u_{xx}
# ====================================================================================================
# SNR =  10000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  4
# Iteration: 3. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (0.116213)u_{xx}
# u_t = (0.588558) + (0.119194)u_{xx} + (-0.000006)u^2 + (-0.000000)u^2u_{xx}
# u_t = (0.681026) + (0.102377)u_{xx} + (0.000092)u_{xxx} + (-0.000586)u + (-0.000005)u^2 + (0.000114)uu_{xx} + (-0.000000)u^2u_{xx}
#
# Desired PDE:  u_t = (0.116213)u_{xx}
# ====================================================================================================
# SNR =  7500
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  4
# Iteration: 3. Number of non-zeros:  8
#
# PDEs Predicted by L0:
# u_t = (0.108084)u_{xx}
# u_t = (0.713297) + (0.114580)u_{xx} + (-0.000007)u^2 + (-0.000000)u^2u_{xx}
# u_t = (0.827795) + (-0.000250)u_{x} + (0.099229)u_{xx} + (-0.000162)u_{xxx} + (-0.000730)u + (-0.000006)u^2 + (0.000104)uu_{xx} + (-0.000000)u^2u_{xx}
#
# Desired PDE:  u_t = (0.108084)u_{xx}
# ====================================================================================================
# SNR =  5000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (0.094077)u_{xx}
# u_t = (0.933749) + (0.103116)u_{xx} + (0.000296)u_{xxx} + (-0.000010)u^2 + (-0.000000)u^2u_{xx}
#
# Desired PDE:  u_t = (0.094077)u_{xx}
# ====================================================================================================
# SNR =  3000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  4
# Iteration: 3. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (0.077047)u_{xx}
# u_t = (1.189408) + (0.088696)u_{xx} + (-0.000012)u^2 + (-0.000000)u^2u_{xx}
# u_t = (1.368698) + (0.078242)u_{xx} + (-0.001161)u + (-0.000010)u^2 + (0.000070)uu_{xx} + (-0.000000)u^2u_{xx} + (0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (0.077047)u_{xx}
# ====================================================================================================
# SNR =  2000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  4
# Iteration: 3. Number of non-zeros:  10
#
# PDEs Predicted by L0:
# u_t = (0.060422)u_{xx}
# u_t = (1.431523) + (0.069899)u_{xx} + (-0.000014)u^2 + (-0.000000)u^2u_{xx}
# u_t = (1.638634) + (0.061925)u_{xx} + (0.000582)u_{xxx} + (-0.001351)u + (-0.000012)u^2 + (0.000000)u^2u_{x} + (0.000053)uu_{xx} + (-0.000000)u^2u_{xx} + (-0.000000)uu_{xxx} + (-0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (0.060422)u_{xx}
# ====================================================================================================
# SNR =  1000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  4
# Iteration: 3. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (0.038018)u_{xx}
# u_t = (1.184289) + (0.033202)u_{xx} + (-0.000012)u^2 + (-0.000000)u^2u_{xxx}
# u_t = (1.725187) + (0.040822)u_{xx} + (-0.001098)u + (-0.000014)u^2 + (0.000033)uu_{xx} + (-0.000000)u^2u_{xx} + (-0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (0.038018)u_{xx}
# ====================================================================================================
# SNR =  800
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  3
# Iteration: 3. Number of non-zeros:  8
#
# PDEs Predicted by L0:
# u_t = (0.032622)u_{xx}
# u_t = (1.089775) + (0.028775)u_{xx} + (-0.000011)u^2
# u_t = (1.603210) + (0.038283)u_{xx} + (-0.001148)u + (-0.000013)u^2 + (0.000000)u^2u_{x} + (0.000026)uu_{xx} + (-0.000000)u^2u_{xx} + (-0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (0.032622)u_{xx}
# ====================================================================================================
# SNR =  500
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  3
# Iteration: 3. Number of non-zeros:  8
#
# PDEs Predicted by L0:
# u_t = (0.021468)u_{xx}
# u_t = (0.838127) + (0.019309)u_{xx} + (-0.000009)u^2
# u_t = (1.290952) + (0.030207)u_{xx} + (-0.001221)u + (-0.000010)u^2 + (0.000014)uu_{xx} + (-0.000000)u^2u_{xx} + (0.000000)uu_{xxx} + (-0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (0.021468)u_{xx}
# ====================================================================================================
# SNR =  300
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  4
# Iteration: 4. Number of non-zeros:  10
#
# PDEs Predicted by L0:
# u_t = (0.013925)u_{xx}
# u_t = (0.012974)u_{xx} + (-0.000005)u^2
# u_t = (0.817009) + (0.012427)u_{xx} + (-0.001226)u + (-0.000007)u^2
# u_t = (0.980410) + (0.018682)u_{xx} + (-0.000542)u_{xxx} + (-0.001317)u + (-0.000008)u^2 + (-0.000000)u^2u_{x} + (0.000017)uu_{xx} + (-0.000000)u^2u_{xx} + (0.000000)uu_{xxx} + (0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (0.013925)u_{xx}
# ====================================================================================================
# SNR =  200
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  2
# Iteration: 4. Number of non-zeros:  2
# Iteration: 5. Number of non-zeros:  2
# Iteration: 6. Number of non-zeros:  2
# Iteration: 7. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (0.009807)u_{xx}
# u_t = (0.009130)u_{xx} + (-0.000004)u^2
# u_t = (0.009130)u_{xx} + (-0.000004)u^2
# u_t = (0.009130)u_{xx} + (-0.000004)u^2
# u_t = (0.009130)u_{xx} + (-0.000004)u^2
# u_t = (0.009130)u_{xx} + (-0.000004)u^2
# u_t = (0.680910) + (0.008841)u_{xx} + (0.000150)u_{xxx} + (-0.001132)u + (-0.000006)u^2
#
# Desired PDE:  u_t = (0.009807)u_{xx}
# ====================================================================================================
# SNR =  100
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  1
# Iteration: 13. Number of non-zeros:  1
# Iteration: 14. Number of non-zeros:  1
# Iteration: 15. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (0.720190) + (0.004780)u_{xx} + (-0.001175)u + (-0.000006)u^2 + (0.000006)uu_{x} + (-0.000000)u^2u_{x} + (0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.000005)u^2
# ====================================================================================================
# SNR =  90
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (0.766494) + (0.003676)u_{xx} + (-0.001304)u + (-0.000006)u^2 + (-0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.000005)u^2
# ====================================================================================================
# SNR =  80
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (0.785170) + (0.003579)u_{xx} + (-0.000203)u_{xxx} + (-0.001348)u + (-0.000006)u^2
#
# Desired PDE:  u_t = (-0.000005)u^2
# ====================================================================================================
# SNR =  70
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  4
# Iteration: 3. Number of non-zeros:  10
#
# PDEs Predicted by L0:
# u_t = (-0.000005)u^2
# u_t = (0.804077) + (0.003574)u_{xx} + (-0.001386)u + (-0.000007)u^2
# u_t = (0.964893) + (0.000681)u_{x} + (0.007895)u_{xx} + (-0.000017)u_{xxx} + (-0.001445)u + (-0.000008)u^2 + (-0.000001)uu_{xx} + (-0.000000)u^2u_{xx} + (0.000000)uu_{xxx} + (0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.000005)u^2
# ====================================================================================================
# SNR =  60
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (0.588000) + (0.002771)u_{xx} + (0.000096)u_{xxx} + (-0.000878)u + (-0.000005)u^2
#
# Desired PDE:  u_t = (-0.000004)u^2
# ====================================================================================================
# SNR =  50
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  4
# Iteration: 5. Number of non-zeros:  4
# Iteration: 6. Number of non-zeros:  4
# Iteration: 7. Number of non-zeros:  4
# Iteration: 8. Number of non-zeros:  4
# Iteration: 9. Number of non-zeros:  4
# Iteration: 10. Number of non-zeros:  4
# Iteration: 11. Number of non-zeros:  4
# Iteration: 12. Number of non-zeros:  4
# Iteration: 13. Number of non-zeros:  4
# Iteration: 14. Number of non-zeros:  4
# Iteration: 15. Number of non-zeros:  4
# Iteration: 16. Number of non-zeros:  11
#
# PDEs Predicted by L0:
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (0.683696) + (0.002502)u_{xx} + (-0.001110)u + (-0.000006)u^2
# u_t = (0.820435) + (0.002452)u_{xx} + (-0.001106)u + (-0.000007)u^2
# u_t = (0.984522) + (0.002392)u_{xx} + (-0.001102)u + (-0.000008)u^2
# u_t = (1.181426) + (0.002319)u_{xx} + (-0.001097)u + (-0.000010)u^2
# u_t = (1.417711) + (0.002233)u_{xx} + (-0.001091)u + (-0.000011)u^2
# u_t = (1.701254) + (0.002128)u_{xx} + (-0.001084)u + (-0.000014)u^2
# u_t = (2.041504) + (0.002003)u_{xx} + (-0.001075)u + (-0.000017)u^2
# u_t = (2.449805) + (0.001877)u_{xx} + (-0.001478)u + (-0.000019)u^2
# u_t = (2.592719) + (0.001853)u_{xx} + (-0.001976)u + (-0.000018)u^2
# u_t = (2.592719) + (0.001853)u_{xx} + (-0.001976)u + (-0.000018)u^2
# u_t = (2.592719) + (0.001853)u_{xx} + (-0.001976)u + (-0.000018)u^2
# u_t = (2.592719) + (0.001853)u_{xx} + (-0.001976)u + (-0.000018)u^2
# u_t = (2.583194) + (0.010132)u_{x} + (0.002899)u_{xx} + (-0.001964)u + (-0.000018)u^2 + (-0.000013)uu_{x} + (-0.000000)u^2u_{x} + (0.000001)uu_{xx} + (-0.000000)u^2u_{xx} + (0.000000)uu_{xxx} + (-0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.000005)u^2
# ====================================================================================================
# SNR =  40
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  4
# Iteration: 4. Number of non-zeros:  12
#
# PDEs Predicted by L0:
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (0.671591) + (0.002163)u_{xx} + (-0.001103)u + (-0.000005)u^2
# u_t = (0.805909) + (0.005927)u_{x} + (0.005260)u_{xx} + (-0.000102)u_{xxx} + (-0.001158)u + (-0.000007)u^2 + (-0.000008)uu_{x} + (0.000000)u^2u_{x} + (-0.000001)uu_{xx} + (-0.000000)u^2u_{xx} + (0.000000)uu_{xxx} + (0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.000005)u^2
# ====================================================================================================
# SNR =  30
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  1
# Iteration: 13. Number of non-zeros:  1
# Iteration: 14. Number of non-zeros:  1
# Iteration: 15. Number of non-zeros:  1
# Iteration: 16. Number of non-zeros:  1
# Iteration: 17. Number of non-zeros:  1
# Iteration: 18. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (0.012119)u_{x}
# u_t = (0.012124)u_{x}
# u_t = (0.012124)u_{x}
# u_t = (0.012124)u_{x}
# u_t = (0.012124)u_{x}
# u_t = (0.012124)u_{x}
# u_t = (0.012124)u_{x}
# u_t = (0.012124)u_{x}
# u_t = (0.012124)u_{x}
# u_t = (0.012124)u_{x}
# u_t = (0.012124)u_{x}
# u_t = (0.012124)u_{x}
# u_t = (0.012124)u_{x}
# u_t = (0.012124)u_{x}
# u_t = (0.012124)u_{x}
# u_t = (0.012124)u_{x}
# u_t = (0.012124)u_{x}
# u_t = (0.791798) + (0.014549)u_{x} + (0.000895)u_{xx} + (-0.000275)u_{xxx} + (-0.001276)u + (-0.000006)u^2 + (-0.000000)u^2u_{x}
#
# Desired PDE:  u_t = (0.012119)u_{x}
# ====================================================================================================
# SNR =  20
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (0.806179) + (0.001086)u_{xx} + (-0.000242)u_{xxx} + (-0.001446)u + (-0.000007)u^2 + (-0.000000)u^2u_{x}
#
# Desired PDE:  u_t = (-0.000005)u^2
# ====================================================================================================
# SNR =  10
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  10
#
# PDEs Predicted by L0:
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (-0.000005)u^2
# u_t = (0.788091) + (-0.002217)u_{x} + (0.000755)u_{xx} + (-0.000207)u_{xxx} + (-0.001355)u + (-0.000006)u^2 + (-0.000025)uu_{x} + (-0.000000)u^2u_{x} + (-0.000000)u^2u_{xx} + (-0.000001)uu_{xxx}
#
# Desired PDE:  u_t = (-0.000005)u^2
# ====================================================================================================
# SNR =  8
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  1
# Iteration: 13. Number of non-zeros:  1
# Iteration: 14. Number of non-zeros:  1
# Iteration: 15. Number of non-zeros:  1
# Iteration: 16. Number of non-zeros:  1
# Iteration: 17. Number of non-zeros:  1
# Iteration: 18. Number of non-zeros:  1
# Iteration: 19. Number of non-zeros:  1
# Iteration: 20. Number of non-zeros:  1
# Iteration: 21. Number of non-zeros:  1
# Iteration: 22. Number of non-zeros:  1
# Iteration: 23. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (-0.000259)u_{xxx}
# u_t = (1.320511) + (0.001845)u_{x} + (-0.000224)u_{xxx} + (-0.001920)u + (-0.000011)u^2 + (0.000000)u^2u_{xx}
#
# Desired PDE:  u_t = (-0.000259)u_{xxx}
# ====================================================================================================
# SNR =  6
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (0.000162)u_{xxx}
# u_t = (0.000162)u_{xxx}
# u_t = (0.000162)u_{xxx}
# u_t = (0.000162)u_{xxx}
# u_t = (0.000162)u_{xxx}
# u_t = (0.000162)u_{xxx}
# u_t = (0.000162)u_{xxx}
# u_t = (0.000162)u_{xxx}
# u_t = (0.000162)u_{xxx}
# u_t = (0.000162)u_{xxx}
# u_t = (0.000162)u_{xxx}
# u_t = (0.958283) + (0.008833)u_{x} + (0.000180)u_{xxx} + (-0.000786)u + (-0.000008)u^2 + (-0.000009)uu_{x} + (-0.000000)u^2u_{x}
#
# Desired PDE:  u_t = (0.000162)u_{xxx}
# ====================================================================================================
# SNR =  5
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  1
# Iteration: 13. Number of non-zeros:  1
# Iteration: 14. Number of non-zeros:  1
# Iteration: 15. Number of non-zeros:  1
# Iteration: 16. Number of non-zeros:  1
# Iteration: 17. Number of non-zeros:  8
#
# PDEs Predicted by L0:
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (-0.000004)u^2
# u_t = (0.673630) + (0.002930)u_{x} + (-0.000249)u_{xx} + (-0.000121)u_{xxx} + (-0.001069)u + (-0.000005)u^2 + (-0.000000)u^2u_{x} + (0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.000004)u^2
# ====================================================================================================
# SNR =  4
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  3
# Iteration: 11. Number of non-zeros:  3
# Iteration: 12. Number of non-zeros:  3
# Iteration: 13. Number of non-zeros:  3
# Iteration: 14. Number of non-zeros:  3
# Iteration: 15. Number of non-zeros:  3
# Iteration: 16. Number of non-zeros:  11
#
# PDEs Predicted by L0:
# u_t = (-0.008130)u_{x}
# u_t = (-0.008138)u_{x}
# u_t = (-0.008138)u_{x}
# u_t = (-0.008138)u_{x}
# u_t = (-0.008138)u_{x}
# u_t = (-0.008138)u_{x}
# u_t = (-0.008138)u_{x}
# u_t = (-0.008138)u_{x}
# u_t = (-0.008138)u_{x}
# u_t = (-0.009766)u_{x} + (-0.000005)u^2 + (-0.000000)u^2u_{xxx}
# u_t = (-0.011719)u_{x} + (-0.000005)u^2 + (-0.000000)u^2u_{xxx}
# u_t = (-0.014063)u_{x} + (-0.000005)u^2 + (-0.000000)u^2u_{xxx}
# u_t = (-0.016875)u_{x} + (-0.000005)u^2 + (-0.000000)u^2u_{xxx}
# u_t = (-0.020250)u_{x} + (-0.000005)u^2 + (-0.000000)u^2u_{xxx}
# u_t = (-0.024301)u_{x} + (-0.000005)u^2 + (-0.000000)u^2u_{xxx}
# u_t = (2.720729) + (-0.010065)u_{x} + (-0.001636)u_{xx} + (0.000112)u_{xxx} + (-0.003101)u + (-0.000015)u^2 + (-0.000053)uu_{x} + (-0.000000)u^2u_{x} + (0.000000)u^2u_{xx} + (-0.000000)uu_{xxx} + (-0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.008130)u_{x}
# ====================================================================================================
# SNR =  3
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  1
# Iteration: 13. Number of non-zeros:  1
# Iteration: 14. Number of non-zeros:  1
# Iteration: 15. Number of non-zeros:  12
#
# PDEs Predicted by L0:
# u_t = (0.012126)u_{x}
# u_t = (0.012132)u_{x}
# u_t = (0.012132)u_{x}
# u_t = (0.012132)u_{x}
# u_t = (0.012132)u_{x}
# u_t = (0.012132)u_{x}
# u_t = (0.012132)u_{x}
# u_t = (0.012132)u_{x}
# u_t = (0.012132)u_{x}
# u_t = (0.012132)u_{x}
# u_t = (0.012132)u_{x}
# u_t = (0.012132)u_{x}
# u_t = (0.012132)u_{x}
# u_t = (0.012132)u_{x}
# u_t = (2.000497) + (0.014558)u_{x} + (0.004395)u_{xx} + (-0.000125)u_{xxx} + (-0.003795)u + (-0.000012)u^2 + (0.000043)uu_{x} + (-0.000000)u^2u_{x} + (-0.000005)uu_{xx} + (-0.000000)u^2u_{xx} + (0.000000)uu_{xxx} + (0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (0.012126)u_{x}
# ====================================================================================================
# SNR =  2
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  1
# Iteration: 13. Number of non-zeros:  1
# Iteration: 14. Number of non-zeros:  1
# Iteration: 15. Number of non-zeros:  1
# Iteration: 16. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (-0.000006)u^2
# u_t = (-0.000006)u^2
# u_t = (-0.000006)u^2
# u_t = (-0.000006)u^2
# u_t = (-0.000006)u^2
# u_t = (-0.000006)u^2
# u_t = (-0.000006)u^2
# u_t = (-0.000006)u^2
# u_t = (-0.000006)u^2
# u_t = (-0.000006)u^2
# u_t = (-0.000006)u^2
# u_t = (-0.000006)u^2
# u_t = (-0.000006)u^2
# u_t = (-0.000006)u^2
# u_t = (-0.000006)u^2
# u_t = (0.902181) + (-0.000107)u_{xxx} + (-0.001798)u + (-0.000007)u^2 + (-0.000008)uu_{x} + (-0.000000)u^2u_{x} + (0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.000006)u^2
# ====================================================================================================
# SNR =  1
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  8
#
# PDEs Predicted by L0:
# u_t = (-0.014192)u_{x}
# u_t = (-0.014199)u_{x}
# u_t = (-0.014199)u_{x}
# u_t = (-0.014199)u_{x}
# u_t = (-0.014199)u_{x}
# u_t = (-0.014199)u_{x}
# u_t = (-0.014199)u_{x}
# u_t = (1.855414) + (-0.014068)u_{x} + (-0.008782)u + (0.000006)u^2 + (-0.000000)uu_{x} + (0.000000)u^2u_{x} + (-0.000001)uu_{xxx} + (0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.014192)u_{x}
# ====================================================================================================
# SNR =  0.9
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (0.011401)u_{x}
# u_t = (2.253873) + (0.013682)u_{x} + (0.000235)u_{xxx} + (-0.000014)u^2 + (0.000039)uu_{x} + (0.000000)u^2u_{xx} + (0.000000)uu_{xxx}
#
# Desired PDE:  u_t = (0.011401)u_{x}
# ====================================================================================================
# SNR =  0.8
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  1
# Iteration: 13. Number of non-zeros:  1
# Iteration: 14. Number of non-zeros:  1
# Iteration: 15. Number of non-zeros:  1
# Iteration: 16. Number of non-zeros:  1
# Iteration: 17. Number of non-zeros:  10
#
# PDEs Predicted by L0:
# u_t = (0.000000)u^2u_{x}
# u_t = (0.000000)u^2u_{x}
# u_t = (0.000000)u^2u_{x}
# u_t = (0.000000)u^2u_{x}
# u_t = (0.000000)u^2u_{x}
# u_t = (0.000000)u^2u_{x}
# u_t = (0.000000)u^2u_{x}
# u_t = (0.000000)u^2u_{x}
# u_t = (0.000000)u^2u_{x}
# u_t = (0.000000)u^2u_{x}
# u_t = (0.000000)u^2u_{x}
# u_t = (0.000000)u^2u_{x}
# u_t = (0.000000)u^2u_{x}
# u_t = (0.000000)u^2u_{x}
# u_t = (0.000000)u^2u_{x}
# u_t = (0.000000)u^2u_{x}
# u_t = (0.895561) + (0.003687)u_{x} + (-0.001643)u_{xx} + (-0.000308)u + (-0.000005)u^2 + (-0.000017)uu_{x} + (0.000000)u^2u_{x} + (0.000000)u^2u_{xx} + (0.000001)uu_{xxx} + (-0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (0.000000)u^2u_{x}
# ====================================================================================================
# SNR =  0.75
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  1
# Iteration: 13. Number of non-zeros:  1
# Iteration: 14. Number of non-zeros:  1
# Iteration: 15. Number of non-zeros:  1
# Iteration: 16. Number of non-zeros:  1
# Iteration: 17. Number of non-zeros:  1
# Iteration: 18. Number of non-zeros:  1
# Iteration: 19. Number of non-zeros:  1
# Iteration: 20. Number of non-zeros:  1
# Iteration: 21. Number of non-zeros:  1
# Iteration: 22. Number of non-zeros:  1
# Iteration: 23. Number of non-zeros:  1
# Iteration: 24. Number of non-zeros:  1
# Iteration: 25. Number of non-zeros:  1
# Iteration: 26. Number of non-zeros:  10
#
# PDEs Predicted by L0:
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (-0.000000)u^2u_{xxx}
# u_t = (1.603159) + (-0.007013)u_{x} + (0.000069)u_{xxx} + (-0.005937)u + (0.000002)u^2 + (-0.000000)u^2u_{x} + (-0.000002)uu_{xx} + (0.000000)u^2u_{xx} + (-0.000000)uu_{xxx} + (-0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.000000)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.7
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  1
# Iteration: 13. Number of non-zeros:  1
# Iteration: 14. Number of non-zeros:  1
# Iteration: 15. Number of non-zeros:  1
# Iteration: 16. Number of non-zeros:  11
#
# PDEs Predicted by L0:
# u_t = (-0.000000)u^2u_{x}
# u_t = (-0.000000)u^2u_{x}
# u_t = (-0.000000)u^2u_{x}
# u_t = (-0.000000)u^2u_{x}
# u_t = (-0.000000)u^2u_{x}
# u_t = (-0.000000)u^2u_{x}
# u_t = (-0.000000)u^2u_{x}
# u_t = (-0.000000)u^2u_{x}
# u_t = (-0.000000)u^2u_{x}
# u_t = (-0.000000)u^2u_{x}
# u_t = (-0.000000)u^2u_{x}
# u_t = (-0.000000)u^2u_{x}
# u_t = (-0.000000)u^2u_{x}
# u_t = (-0.000000)u^2u_{x}
# u_t = (-0.000000)u^2u_{x}
# u_t = (-0.000538)u_{x} + (-0.001005)u_{xx} + (-0.000127)u_{xxx} + (0.003004)u + (-0.000007)u^2 + (-0.000012)uu_{x} + (-0.000000)u^2u_{x} + (-0.000004)uu_{xx} + (0.000000)u^2u_{xx} + (-0.000000)uu_{xxx} + (0.000000)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.000000)u^2u_{x}
# ====================================================================================================
# SNR =  0.6
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  8
#
# PDEs Predicted by L0:
# u_t = (-0.003530)u_{x}
# u_t = (-0.003530)u_{x}
# u_t = (-0.003530)u_{x}
# u_t = (-0.003530)u_{x}
# u_t = (-0.003530)u_{x}
# u_t = (-0.003530)u_{x}
# u_t = (-0.003530)u_{x}
# u_t = (-0.003530)u_{x}
# u_t = (-0.003530)u_{x}
# u_t = (-0.003530)u_{x}
# u_t = (0.446976) + (-0.004236)u_{x} + (0.000298)u_{xx} + (0.000091)u_{xxx} + (0.000645)u + (-0.000009)u^2 + (0.000012)uu_{x} + (0.000000)u^2u_{x}
#
# Desired PDE:  u_t = (-0.003530)u_{x}
# ====================================================================================================
# SNR =  0.5
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  8
#
# PDEs Predicted by L0:
# u_t = (0.000260)u_{xxx}
# u_t = (0.011117)u_{x} + (-0.000665)u_{xx} + (0.000312)u_{xxx} + (0.009717)u + (-0.000031)u^2 + (0.000007)uu_{x} + (0.000000)u^2u_{x} + (0.000001)uu_{xxx}
#
# Desired PDE:  u_t = (0.000260)u_{xxx}
# ====================================================================================================
# SNR =  0.4
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.000000)u^2u_{x}
# u_t = (-0.000000)u^2u_{x}
# u_t = (-0.006737)u_{x} + (-0.000144)u_{xxx} + (-0.000008)u^2 + (-0.000012)uu_{x} + (-0.000000)u^2u_{x} + (-0.000000)uu_{xxx}
#
# Desired PDE:  u_t = (-0.000000)u^2u_{x}
# ====================================================================================================
# SNR =  0.3
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (0.014770)u_{x}
# u_t = (0.014777)u_{x}
# u_t = (0.014777)u_{x}
# u_t = (0.014777)u_{x}
# u_t = (0.014777)u_{x}
# u_t = (0.014777)u_{x}
# u_t = (0.014777)u_{x}
# u_t = (0.017733)u_{x} + (0.004369)u_{xx} + (-0.000143)u_{xxx} + (-0.004589)u + (-0.000030)uu_{x} + (-0.000000)uu_{xx} + (-0.000000)u^2u_{xx}
#
# Desired PDE:  u_t = (0.014770)u_{x}
# ====================================================================================================
# SNR =  0.25
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  9
#
# PDEs Predicted by L0:
# u_t = (-0.000035)uu_{x}
# u_t = (-0.000035)uu_{x}
# u_t = (-0.000035)uu_{x}
# u_t = (-0.000035)uu_{x}
# u_t = (-0.000035)uu_{x}
# u_t = (0.437099) + (-0.007496)u_{x} + (-0.000617)u_{xx} + (0.000002)u_{xxx} + (-0.000008)u^2 + (-0.000042)uu_{x} + (-0.000000)u^2u_{x} + (0.000003)uu_{xx} + (-0.000001)uu_{xxx}
#
# Desired PDE:  u_t = (-0.000035)uu_{x}
# ====================================================================================================
# SNR =  0.2
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (0.000000)u^2u_{xx}
# u_t = (0.000000)u^2u_{xx}
# u_t = (0.000000)u^2u_{xx}
# u_t = (0.000000)u^2u_{xx}
# u_t = (0.002836)u_{x} + (-0.001067)u_{xx} + (-0.000024)u_{xxx} + (-0.000012)uu_{x} + (-0.000000)u^2u_{x} + (0.000000)u^2u_{xx} + (-0.000000)uu_{xxx}
#
# Desired PDE:  u_t = (0.000000)u^2u_{xx}
# ====================================================================================================
# SNR =  0.1
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.000000)uu_{xxx}
# u_t = (-0.000000)uu_{xxx}
# u_t = (-0.000000)uu_{xxx}
# u_t = (-0.000000)uu_{xxx}
# u_t = (-0.000000)uu_{xxx}
# u_t = (-0.000000)uu_{xxx}
# u_t = (-0.000000)uu_{xxx}
# u_t = (-0.000000)uu_{xxx}
# u_t = (-0.000000)uu_{xxx}
# u_t = (-0.000000)uu_{xxx}
# u_t = (-0.000000)uu_{xxx}
# u_t = (-0.005863)u_{x} + (-0.001002)u_{xx} + (0.000000)u^2u_{x} + (0.000000)u^2u_{xx} + (-0.000000)uu_{xxx}
#
# Desired PDE:  u_t = (-0.000000)uu_{xxx}

# %%
# Burgers equation ut = 0.1uxx -1 uux

pred_coefficients=[]

snrs = ["No noise",20000,15000,10000,7500,5000,3000,2000,1000,800,500,300,200,100,90,80,70,60,50,40,30,20,10,8,6,5,4,3,2,1,0.9,0.8,0.75,0.7,0.6,0.5,0.4,0.3,0.25,0.2,0.1]

for j in range(len(snrs)):
    print("="*100)
    print("SNR = ",snrs[j])

    # Loading u,x,t
    path = data_path+"/2_"+str(j)+".pkl"
    sols,descr = discover_pde(path)
    print("\nPDEs Predicted by L0: ")
    for i in range(len(sols)):
        print(return_pde(sols[i]["B"], descr))
    
    # Desired PDE
    w= sols[1]["B"]
    print("\nDesired PDE: ", return_pde(w, descr))
    pred_coefficients.append([snrs[j]]+list(w))
    
df_2 = pd.DataFrame(pred_coefficients, columns = ["SNR"]+descr )
df_2.to_csv(results_path+"/burgerseqn_results.csv")
# Out:
# ====================================================================================================
# SNR =  No noise
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.355532)u_{x}
# u_t = (0.101836)u_{xx} + (-0.973142)uu_{x}
# u_t = (-0.094720)u_{x} + (0.094322)u_{xx} + (0.003896)u_{xxx} + (-0.475850)uu_{x} + (-0.490012)u^2u_{x}
#
# Desired PDE:  u_t = (0.101836)u_{xx} + (-0.973142)uu_{x}
# ====================================================================================================
# SNR =  20000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.354773)u_{x}
# u_t = (0.099683)u_{xx} + (-0.970173)uu_{x}
# u_t = (-0.106290)u_{x} + (0.076788)u_{xx} + (-0.494621)uu_{x} + (-0.491524)u^2u_{x} + (0.038688)uu_{xx}
#
# Desired PDE:  u_t = (0.099683)u_{xx} + (-0.970173)uu_{x}
# ====================================================================================================
# SNR =  15000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.354488)u_{x}
# u_t = (0.099007)u_{xx} + (-0.968911)uu_{x}
# u_t = (-0.107811)u_{x} + (0.075274)u_{xx} + (-0.491054)uu_{x} + (-0.490641)u^2u_{x} + (0.040465)uu_{xx}
#
# Desired PDE:  u_t = (0.099007)u_{xx} + (-0.968911)uu_{x}
# ====================================================================================================
# SNR =  10000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.354023)u_{x}
# u_t = (0.097667)u_{xx} + (-0.966887)uu_{x}
# u_t = (-0.108740)u_{x} + (0.070983)u_{xx} + (-0.494141)uu_{x} + (-0.523311)u^2u_{x} + (0.054461)uu_{xx} + (-0.007701)u^2u_{xxx}
#
# Desired PDE:  u_t = (0.097667)u_{xx} + (-0.966887)uu_{x}
# ====================================================================================================
# SNR =  7500
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.353607)u_{x}
# u_t = (0.096319)u_{xx} + (-0.965937)uu_{x}
# u_t = (-0.111198)u_{x} + (0.068066)u_{xx} + (-0.487639)uu_{x} + (-0.528481)u^2u_{x} + (0.058716)uu_{xx} + (-0.008026)u^2u_{xxx}
#
# Desired PDE:  u_t = (0.096319)u_{xx} + (-0.965937)uu_{x}
# ====================================================================================================
# SNR =  5000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.352747)u_{x}
# u_t = (0.093810)u_{xx} + (-0.962446)uu_{x}
# u_t = (-0.114979)u_{x} + (0.063004)u_{xx} + (-0.477793)uu_{x} + (-0.531788)u^2u_{x} + (0.065694)uu_{xx} + (-0.008198)u^2u_{xxx}
#
# Desired PDE:  u_t = (0.093810)u_{xx} + (-0.962446)uu_{x}
# ====================================================================================================
# SNR =  3000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.350818)u_{x}
# u_t = (0.089079)u_{xx} + (-0.955855)uu_{x}
# u_t = (-0.122589)u_{x} + (0.054960)u_{xx} + (-0.475447)uu_{x} + (-0.511026)u^2u_{x} + (0.074499)uu_{xx} + (-0.005524)uu_{xxx}
#
# Desired PDE:  u_t = (0.089079)u_{xx} + (-0.955855)uu_{x}
# ====================================================================================================
# SNR =  2000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.348463)u_{x}
# u_t = (0.083851)u_{xx} + (-0.949217)uu_{x}
# u_t = (-0.141232)u_{x} + (0.045201)u_{xx} + (-0.001453)u_{xxx} + (-0.416343)uu_{x} + (-0.518458)u^2u_{x} + (0.081841)uu_{xx}
#
# Desired PDE:  u_t = (0.083851)u_{xx} + (-0.949217)uu_{x}
# ====================================================================================================
# SNR =  1000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.856726)uu_{x}
# u_t = (0.070878)u_{xx} + (-0.930214)uu_{x}
# u_t = (-0.132780)u_{x} + (0.032275)u_{xx} + (-0.465889)uu_{x} + (-0.488061)u^2u_{x} + (0.102003)uu_{xx} + (-0.006591)uu_{xxx}
#
# Desired PDE:  u_t = (0.070878)u_{xx} + (-0.930214)uu_{x}
# ====================================================================================================
# SNR =  800
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  4
# Iteration: 4. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (-0.855190)uu_{x}
# u_t = (0.066215)u_{xx} + (-0.923565)uu_{x}
# u_t = (-0.237588)u_{x} + (-0.001995)u_{xxx} + (-0.903337)u^2u_{x} + (0.143259)uu_{xx}
# u_t = (-0.157856)u_{x} + (0.025920)u_{xx} + (-0.001211)u_{xxx} + (-0.386375)uu_{x} + (-0.527472)u^2u_{x} + (0.106348)uu_{xx} + (-0.003492)uu_{xxx}
#
# Desired PDE:  u_t = (0.066215)u_{xx} + (-0.923565)uu_{x}
# ====================================================================================================
# SNR =  500
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  4
# Iteration: 4. Number of non-zeros:  9
#
# PDEs Predicted by L0:
# u_t = (-0.846360)uu_{x}
# u_t = (-0.955126)uu_{x} + (0.140933)uu_{xx}
# u_t = (-0.237861)u_{x} + (-0.002015)u_{xxx} + (-0.879725)u^2u_{x} + (0.134810)uu_{xx}
# u_t = (0.004496) + (-0.169725)u_{x} + (0.016237)u_{xx} + (-0.001225)u_{xxx} + (-0.054527)u^2 + (-0.375707)uu_{x} + (-0.447580)u^2u_{x} + (0.085798)uu_{xx} + (-0.003954)uu_{xxx}
#
# Desired PDE:  u_t = (-0.955126)uu_{x} + (0.140933)uu_{xx}
# ====================================================================================================
# SNR =  300
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  4
# Iteration: 4. Number of non-zeros:  8
#
# PDEs Predicted by L0:
# u_t = (-0.837896)uu_{x}
# u_t = (-0.935895)uu_{x} + (0.128625)uu_{xx}
# u_t = (-0.103343)u_{x} + (-0.763962)uu_{x} + (0.127125)uu_{xx} + (-0.006743)uu_{xxx}
# u_t = (0.005283) + (-0.181094)u_{x} + (-0.001231)u_{xxx} + (-0.068821)u^2 + (-0.356773)uu_{x} + (-0.414618)u^2u_{x} + (0.095677)uu_{xx} + (-0.003639)uu_{xxx}
#
# Desired PDE:  u_t = (-0.935895)uu_{x} + (0.128625)uu_{xx}
# ====================================================================================================
# SNR =  200
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  3
# Iteration: 4. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.819764)uu_{x}
# u_t = (-0.904084)uu_{x} + (0.112031)uu_{xx}
# u_t = (-0.977096)uu_{x} + (0.123354)uu_{xx} + (-0.006614)uu_{xxx}
# u_t = (-0.148631)u_{x} + (-0.001182)u_{xxx} + (-0.067324)u^2 + (-0.618135)uu_{x} + (0.075013)uu_{xx} + (-0.003672)uu_{xxx}
#
# Desired PDE:  u_t = (-0.904084)uu_{x} + (0.112031)uu_{xx}
# ====================================================================================================
# SNR =  100
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  3
# Iteration: 3. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (-0.779395)uu_{x}
# u_t = (-0.932300)uu_{x} + (0.095594)uu_{xx} + (-0.011656)u^2u_{xxx}
# u_t = (-0.152059)u_{x} + (-0.001151)u_{xxx} + (0.077880)u + (-0.242616)u^2 + (-0.568471)uu_{x} + (0.042120)u^2u_{xx} + (-0.004029)uu_{xxx}
#
# Desired PDE:  u_t = (-0.932300)uu_{x} + (0.095594)uu_{xx} + (-0.011656)u^2u_{xxx}
# ====================================================================================================
# SNR =  90
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  3
# Iteration: 3. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (-0.763326)uu_{x}
# u_t = (-0.134938)u^2 + (-0.859486)uu_{x} + (-0.006047)uu_{xxx}
# u_t = (-0.146475)u_{x} + (-0.001191)u_{xxx} + (0.076774)u + (-0.238842)u^2 + (-0.573673)uu_{x} + (0.032803)uu_{xx} + (-0.003867)uu_{xxx}
#
# Desired PDE:  u_t = (-0.134938)u^2 + (-0.859486)uu_{x} + (-0.006047)uu_{xxx}
# ====================================================================================================
# SNR =  80
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  3
# Iteration: 3. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (-0.748880)uu_{x}
# u_t = (-0.898656)uu_{x} + (0.079176)uu_{xx} + (-0.006638)uu_{xxx}
# u_t = (-0.151598)u_{x} + (-0.001204)u_{xxx} + (0.076938)u + (-0.241985)u^2 + (-0.563136)uu_{x} + (0.027512)uu_{xx} + (-0.004112)uu_{xxx}
#
# Desired PDE:  u_t = (-0.898656)uu_{x} + (0.079176)uu_{xx} + (-0.006638)uu_{xxx}
# ====================================================================================================
# SNR =  70
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  3
# Iteration: 4. Number of non-zeros:  8
#
# PDEs Predicted by L0:
# u_t = (-0.740148)uu_{x}
# u_t = (-0.853571)uu_{x} + (-0.005954)uu_{xxx}
# u_t = (-0.926304)uu_{x} + (0.127963)u^2u_{xx} + (-0.006745)uu_{xxx}
# u_t = (0.004555) + (-0.142422)u_{x} + (-0.001150)u_{xxx} + (0.058049)u + (-0.228140)u^2 + (-0.575593)uu_{x} + (0.025349)uu_{xx} + (-0.003985)uu_{xxx}
#
# Desired PDE:  u_t = (-0.853571)uu_{x} + (-0.005954)uu_{xxx}
# ====================================================================================================
# SNR =  60
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  2
# Iteration: 4. Number of non-zeros:  2
# Iteration: 5. Number of non-zeros:  3
# Iteration: 6. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (-0.733333)uu_{x}
# u_t = (-0.854270)uu_{x} + (-0.005869)uu_{xxx}
# u_t = (-0.854270)uu_{x} + (-0.005869)uu_{xxx}
# u_t = (-0.854270)uu_{x} + (-0.005869)uu_{xxx}
# u_t = (-0.917614)uu_{x} + (0.076806)uu_{xx} + (-0.006471)uu_{xxx}
# u_t = (-0.136357)u_{x} + (-0.000979)u_{xxx} + (0.079227)u + (-0.250315)u^2 + (-0.589159)uu_{x} + (0.025606)uu_{xx} + (-0.004246)uu_{xxx}
#
# Desired PDE:  u_t = (-0.854270)uu_{x} + (-0.005869)uu_{xxx}
# ====================================================================================================
# SNR =  50
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  2
# Iteration: 4. Number of non-zeros:  2
# Iteration: 5. Number of non-zeros:  2
# Iteration: 6. Number of non-zeros:  3
# Iteration: 7. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (-0.707992)uu_{x}
# u_t = (-0.849590)uu_{x} + (-0.005983)uu_{xxx}
# u_t = (-0.849839)uu_{x} + (-0.005985)uu_{xxx}
# u_t = (-0.849839)uu_{x} + (-0.005985)uu_{xxx}
# u_t = (-0.849839)uu_{x} + (-0.005985)uu_{xxx}
# u_t = (-0.910646)uu_{x} + (0.113491)u^2u_{xx} + (-0.006571)uu_{xxx}
# u_t = (-0.131239)u_{x} + (-0.001132)u_{xxx} + (0.081598)u + (-0.258175)u^2 + (-0.588309)uu_{x} + (0.020057)uu_{xx} + (-0.003893)uu_{xxx}
#
# Desired PDE:  u_t = (-0.849590)uu_{x} + (-0.005983)uu_{xxx}
# ====================================================================================================
# SNR =  40
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  3
# Iteration: 3. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (-0.672305)uu_{x}
# u_t = (-0.136240)u^2 + (-0.806767)uu_{x} + (-0.005754)uu_{xxx}
# u_t = (-0.137843)u_{x} + (0.002500)u_{xx} + (-0.001026)u_{xxx} + (-0.109321)u^2 + (-0.560604)uu_{x} + (0.033349)u^2u_{xx} + (-0.004032)uu_{xxx}
#
# Desired PDE:  u_t = (-0.136240)u^2 + (-0.806767)uu_{x} + (-0.005754)uu_{xxx}
# ====================================================================================================
# SNR =  30
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  2
# Iteration: 4. Number of non-zeros:  2
# Iteration: 5. Number of non-zeros:  2
# Iteration: 6. Number of non-zeros:  2
# Iteration: 7. Number of non-zeros:  2
# Iteration: 8. Number of non-zeros:  2
# Iteration: 9. Number of non-zeros:  2
# Iteration: 10. Number of non-zeros:  2
# Iteration: 11. Number of non-zeros:  2
# Iteration: 12. Number of non-zeros:  2
# Iteration: 13. Number of non-zeros:  2
# Iteration: 14. Number of non-zeros:  2
# Iteration: 15. Number of non-zeros:  2
# Iteration: 16. Number of non-zeros:  2
# Iteration: 17. Number of non-zeros:  2
# Iteration: 18. Number of non-zeros:  2
# Iteration: 19. Number of non-zeros:  2
# Iteration: 20. Number of non-zeros:  2
# Iteration: 21. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.617501)uu_{x}
# u_t = (-0.617512)uu_{x}
# u_t = (-0.741014)uu_{x} + (-0.005276)uu_{xxx}
# u_t = (-0.814198)uu_{x} + (-0.005873)uu_{xxx}
# u_t = (-0.814198)uu_{x} + (-0.005873)uu_{xxx}
# u_t = (-0.814198)uu_{x} + (-0.005873)uu_{xxx}
# u_t = (-0.814198)uu_{x} + (-0.005873)uu_{xxx}
# u_t = (-0.814198)uu_{x} + (-0.005873)uu_{xxx}
# u_t = (-0.814198)uu_{x} + (-0.005873)uu_{xxx}
# u_t = (-0.814198)uu_{x} + (-0.005873)uu_{xxx}
# u_t = (-0.814198)uu_{x} + (-0.005873)uu_{xxx}
# u_t = (-0.814198)uu_{x} + (-0.005873)uu_{xxx}
# u_t = (-0.814198)uu_{x} + (-0.005873)uu_{xxx}
# u_t = (-0.814198)uu_{x} + (-0.005873)uu_{xxx}
# u_t = (-0.814198)uu_{x} + (-0.005873)uu_{xxx}
# u_t = (-0.814198)uu_{x} + (-0.005873)uu_{xxx}
# u_t = (-0.814198)uu_{x} + (-0.005873)uu_{xxx}
# u_t = (-0.814198)uu_{x} + (-0.005873)uu_{xxx}
# u_t = (-0.814198)uu_{x} + (-0.005873)uu_{xxx}
# u_t = (-0.814198)uu_{x} + (-0.005873)uu_{xxx}
# u_t = (0.004349)u_{xx} + (0.086008)u + (-0.274627)u^2 + (-0.822483)uu_{x} + (-0.006026)uu_{xxx}
#
# Desired PDE:  u_t = (-0.617512)uu_{x}
# ====================================================================================================
# SNR =  20
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  2
# Iteration: 5. Number of non-zeros:  2
# Iteration: 6. Number of non-zeros:  2
# Iteration: 7. Number of non-zeros:  2
# Iteration: 8. Number of non-zeros:  2
# Iteration: 9. Number of non-zeros:  2
# Iteration: 10. Number of non-zeros:  2
# Iteration: 11. Number of non-zeros:  2
# Iteration: 12. Number of non-zeros:  2
# Iteration: 13. Number of non-zeros:  2
# Iteration: 14. Number of non-zeros:  2
# Iteration: 15. Number of non-zeros:  2
# Iteration: 16. Number of non-zeros:  2
# Iteration: 17. Number of non-zeros:  2
# Iteration: 18. Number of non-zeros:  2
# Iteration: 19. Number of non-zeros:  2
# Iteration: 20. Number of non-zeros:  2
# Iteration: 21. Number of non-zeros:  2
# Iteration: 22. Number of non-zeros:  2
# Iteration: 23. Number of non-zeros:  2
# Iteration: 24. Number of non-zeros:  2
# Iteration: 25. Number of non-zeros:  2
# Iteration: 26. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.518059)uu_{x}
# u_t = (-0.518059)uu_{x}
# u_t = (-0.518059)uu_{x}
# u_t = (-0.621670)uu_{x} + (-0.004757)uu_{xxx}
# u_t = (-0.746004)uu_{x} + (-0.005751)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (-0.779602)uu_{x} + (-0.006020)uu_{xxx}
# u_t = (0.004798) + (0.002486)u_{xx} + (0.063430)u + (-0.254531)u^2 + (-0.785890)uu_{x} + (-0.006129)uu_{xxx}
#
# Desired PDE:  u_t = (-0.518059)uu_{x}
# ====================================================================================================
# SNR =  10
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  3
# Iteration: 9. Number of non-zeros:  3
# Iteration: 10. Number of non-zeros:  3
# Iteration: 11. Number of non-zeros:  9
#
# PDEs Predicted by L0:
# u_t = (-0.377191)uu_{x}
# u_t = (-0.377191)uu_{x}
# u_t = (-0.377191)uu_{x}
# u_t = (-0.377191)uu_{x}
# u_t = (-0.377191)uu_{x}
# u_t = (-0.377191)uu_{x}
# u_t = (-0.377191)uu_{x}
# u_t = (-0.047298)u + (-0.452629)uu_{x} + (-0.003589)uu_{xxx}
# u_t = (-0.047427)u + (-0.543155)uu_{x} + (-0.004286)uu_{xxx}
# u_t = (-0.047583)u + (-0.651785)uu_{x} + (-0.005122)uu_{xxx}
# u_t = (0.005431) + (-0.068575)u_{x} + (0.000854)u_{xx} + (-0.000593)u_{xxx} + (0.046118)u + (-0.221999)u^2 + (-0.581969)uu_{x} + (-0.003983)uu_{xxx} + (-0.001062)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.377191)uu_{x}
# ====================================================================================================
# SNR =  8
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  4
# Iteration: 12. Number of non-zeros:  4
# Iteration: 13. Number of non-zeros:  9
#
# PDEs Predicted by L0:
# u_t = (-0.326065)uu_{x}
# u_t = (-0.326065)uu_{x}
# u_t = (-0.326065)uu_{x}
# u_t = (-0.326065)uu_{x}
# u_t = (-0.326065)uu_{x}
# u_t = (-0.326065)uu_{x}
# u_t = (-0.326065)uu_{x}
# u_t = (-0.326065)uu_{x}
# u_t = (-0.326065)uu_{x}
# u_t = (-0.326065)uu_{x}
# u_t = (-0.040479)u_{x} + (-0.049550)u + (-0.391278)uu_{x} + (-0.003720)uu_{xxx}
# u_t = (-0.033614)u_{x} + (-0.049655)u + (-0.469533)uu_{x} + (-0.004196)uu_{xxx}
# u_t = (0.005665) + (-0.052473)u_{x} + (0.000848)u_{xx} + (-0.000319)u_{xxx} + (0.046115)u + (-0.227563)u^2 + (-0.555223)uu_{x} + (-0.003819)uu_{xxx} + (-0.001423)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.326065)uu_{x}
# ====================================================================================================
# SNR =  6
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.302803)uu_{x}
# u_t = (-0.302817)uu_{x}
# u_t = (-0.302817)uu_{x}
# u_t = (-0.302817)uu_{x}
# u_t = (-0.302817)uu_{x}
# u_t = (-0.302817)uu_{x}
# u_t = (-0.302817)uu_{x}
# u_t = (-0.302817)uu_{x}
# u_t = (-0.302817)uu_{x}
# u_t = (-0.302817)uu_{x}
# u_t = (0.007323) + (-0.094606)u_{x} + (-0.000800)u_{xxx} + (-0.145561)u^2 + (-0.363380)uu_{x} + (-0.002293)uu_{xxx}
#
# Desired PDE:  u_t = (-0.302817)uu_{x}
# ====================================================================================================
# SNR =  5
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.261349)uu_{x}
# u_t = (-0.261349)uu_{x}
# u_t = (-0.261349)uu_{x}
# u_t = (-0.261349)uu_{x}
# u_t = (-0.261349)uu_{x}
# u_t = (-0.261349)uu_{x}
# u_t = (-0.261349)uu_{x}
# u_t = (-0.261349)uu_{x}
# u_t = (-0.261349)uu_{x}
# u_t = (-0.261349)uu_{x}
# u_t = (-0.122211)u^2 + (-0.313619)uu_{x} + (-0.485250)u^2u_{x} + (-0.001640)uu_{xxx} + (-0.004946)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.261349)uu_{x}
# ====================================================================================================
# SNR =  4
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  1
# Iteration: 13. Number of non-zeros:  1
# Iteration: 14. Number of non-zeros:  8
#
# PDEs Predicted by L0:
# u_t = (-0.208253)uu_{x}
# u_t = (-0.208253)uu_{x}
# u_t = (-0.208253)uu_{x}
# u_t = (-0.208253)uu_{x}
# u_t = (-0.208253)uu_{x}
# u_t = (-0.208253)uu_{x}
# u_t = (-0.208253)uu_{x}
# u_t = (-0.208253)uu_{x}
# u_t = (-0.208253)uu_{x}
# u_t = (-0.208253)uu_{x}
# u_t = (-0.208253)uu_{x}
# u_t = (-0.208253)uu_{x}
# u_t = (-0.208253)uu_{x}
# u_t = (0.006795) + (-0.065253)u_{x} + (-0.000460)u_{xxx} + (-0.132094)u^2 + (-0.249904)uu_{x} + (-0.229046)u^2u_{x} + (-0.001295)uu_{xxx} + (-0.002882)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.208253)uu_{x}
# ====================================================================================================
# SNR =  3
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  8
#
# PDEs Predicted by L0:
# u_t = (-0.157827)uu_{x}
# u_t = (-0.157841)uu_{x}
# u_t = (-0.157841)uu_{x}
# u_t = (-0.157841)uu_{x}
# u_t = (-0.157841)uu_{x}
# u_t = (-0.157841)uu_{x}
# u_t = (-0.157841)uu_{x}
# u_t = (-0.157841)uu_{x}
# u_t = (0.006696) + (-0.040152)u_{x} + (-0.000319)u_{xxx} + (-0.127407)u^2 + (-0.189409)uu_{x} + (-0.320096)u^2u_{x} + (-0.001360)uu_{xxx} + (-0.001883)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.157841)uu_{x}
# ====================================================================================================
# SNR =  2
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.183947)u^2u_{x}
# u_t = (-0.183947)u^2u_{x}
# u_t = (-0.183947)u^2u_{x}
# u_t = (-0.090408)u^2 + (-0.121745)uu_{x} + (-0.220737)u^2u_{x} + (-0.001073)uu_{xxx} + (-0.001468)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.183947)u^2u_{x}
# ====================================================================================================
# SNR =  1
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  7
#
# PDEs Predicted by L0:
# u_t = (-0.059269)uu_{x}
# u_t = (-0.059269)uu_{x}
# u_t = (-0.059269)uu_{x}
# u_t = (-0.020322)u_{x} + (-0.000133)u_{xxx} + (-0.079154)u^2 + (-0.071122)uu_{x} + (-0.126908)u^2u_{x} + (-0.000452)uu_{xxx} + (-0.001109)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.059269)uu_{x}
# ====================================================================================================
# SNR =  0.9
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.066465)u^2u_{x}
# u_t = (-0.066497)u^2u_{x}
# u_t = (-0.009572)u_{x} + (-0.069328)u^2 + (-0.044068)uu_{x} + (-0.079797)u^2u_{x} + (-0.000373)uu_{xxx} + (-0.000677)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.066497)u^2u_{x}
# ====================================================================================================
# SNR =  0.8
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  9
#
# PDEs Predicted by L0:
# u_t = (-0.039761)u^2u_{x}
# u_t = (-0.006188)u_{x} + (-0.008907)u + (-0.054600)u^2 + (-0.028051)uu_{x} + (-0.047713)u^2u_{x} + (-0.003107)uu_{xx} + (-0.003621)u^2u_{xx} + (-0.000239)uu_{xxx} + (-0.000409)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.006188)u_{x} + (-0.008907)u + (-0.054600)u^2 + (-0.028051)uu_{x} + (-0.047713)u^2u_{x} + (-0.003107)uu_{xx} + (-0.003621)u^2u_{xx} + (-0.000239)uu_{xxx} + (-0.000409)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.75
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  10
#
# PDEs Predicted by L0:
# u_t = (-0.010966)u_{x}
# u_t = (0.006811) + (-0.013159)u_{x} + (-0.000066)u_{xxx} + (-0.014059)u + (-0.065910)u^2 + (-0.043341)uu_{x} + (-0.073501)u^2u_{x} + (-0.004481)uu_{xx} + (-0.000368)uu_{xxx} + (-0.000506)u^2u_{xxx}
#
# Desired PDE:  u_t = (0.006811) + (-0.013159)u_{x} + (-0.000066)u_{xxx} + (-0.014059)u + (-0.065910)u^2 + (-0.043341)uu_{x} + (-0.073501)u^2u_{x} + (-0.004481)uu_{xx} + (-0.000368)uu_{xxx} + (-0.000506)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.7
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  3
# Iteration: 3. Number of non-zeros:  3
# Iteration: 4. Number of non-zeros:  3
# Iteration: 5. Number of non-zeros:  9
#
# PDEs Predicted by L0:
# u_t = (-0.068984)u^2
# u_t = (-0.069433)u^2 + (-0.040215)uu_{x} + (-0.000559)u^2u_{xxx}
# u_t = (-0.069457)u^2 + (-0.048258)uu_{x} + (-0.000632)u^2u_{xxx}
# u_t = (-0.069486)u^2 + (-0.057909)uu_{x} + (-0.000720)u^2u_{xxx}
# u_t = (0.008117) + (-0.021275)u_{x} + (-0.000174)u_{xxx} + (-0.094926)u^2 + (-0.068322)uu_{x} + (-0.003139)uu_{xx} + (0.004552)u^2u_{xx} + (-0.000113)uu_{xxx} + (-0.000659)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.069433)u^2 + (-0.040215)uu_{x} + (-0.000559)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.6
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  4
# Iteration: 4. Number of non-zeros:  4
# Iteration: 5. Number of non-zeros:  8
#
# PDEs Predicted by L0:
# u_t = (-0.009544)u_{x}
# u_t = (-0.009544)u_{x}
# u_t = (-0.011453)u_{x} + (-0.032465)u^2 + (-0.020380)uu_{x} + (-0.000486)u^2u_{xxx}
# u_t = (-0.013216)u_{x} + (-0.032408)u^2 + (-0.022715)uu_{x} + (-0.000583)u^2u_{xxx}
# u_t = (0.003381) + (-0.016492)u_{x} + (-0.000049)u_{xxx} + (-0.007732)u + (-0.032844)u^2 + (-0.051348)uu_{x} + (-0.000270)uu_{xxx} + (-0.000699)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.009544)u_{x}
# ====================================================================================================
# SNR =  0.5
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  5
#
# PDEs Predicted by L0:
# u_t = (-0.000200)uu_{xxx}
# u_t = (-0.000200)uu_{xxx}
# u_t = (-0.000200)uu_{xxx}
# u_t = (-0.000200)uu_{xxx}
# u_t = (-0.000200)uu_{xxx}
# u_t = (-0.000200)uu_{xxx}
# u_t = (-0.000200)uu_{xxx}
# u_t = (-0.000200)uu_{xxx}
# u_t = (0.006950) + (-0.064159)u^2 + (-0.028946)u^2u_{x} + (-0.002930)uu_{xx} + (-0.000240)uu_{xxx}
#
# Desired PDE:  u_t = (-0.000200)uu_{xxx}
# ====================================================================================================
# SNR =  0.4
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  1
# Iteration: 13. Number of non-zeros:  1
# Iteration: 14. Number of non-zeros:  1
# Iteration: 15. Number of non-zeros:  1
# Iteration: 16. Number of non-zeros:  1
# Iteration: 17. Number of non-zeros:  10
#
# PDEs Predicted by L0:
# u_t = (-0.016230)u
# u_t = (-0.016246)u
# u_t = (-0.016246)u
# u_t = (-0.016246)u
# u_t = (-0.016246)u
# u_t = (-0.016246)u
# u_t = (-0.016246)u
# u_t = (-0.016246)u
# u_t = (-0.016246)u
# u_t = (-0.016246)u
# u_t = (-0.016246)u
# u_t = (-0.016246)u
# u_t = (-0.016246)u
# u_t = (-0.016246)u
# u_t = (-0.016246)u
# u_t = (-0.016246)u
# u_t = (0.004751) + (-0.000177)u_{x} + (0.000601)u_{xx} + (-0.000032)u_{xxx} + (-0.011578)u + (-0.029886)u^2 + (-0.012971)u^2u_{x} + (-0.002105)uu_{xx} + (-0.001330)u^2u_{xx} + (-0.000041)uu_{xxx}
#
# Desired PDE:  u_t = (-0.016246)u
# ====================================================================================================
# SNR =  0.3
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  1
# Iteration: 13. Number of non-zeros:  1
# Iteration: 14. Number of non-zeros:  1
# Iteration: 15. Number of non-zeros:  1
# Iteration: 16. Number of non-zeros:  1
# Iteration: 17. Number of non-zeros:  1
# Iteration: 18. Number of non-zeros:  1
# Iteration: 19. Number of non-zeros:  1
# Iteration: 20. Number of non-zeros:  1
# Iteration: 21. Number of non-zeros:  1
# Iteration: 22. Number of non-zeros:  9
#
# PDEs Predicted by L0:
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (-0.000228)u^2u_{xxx}
# u_t = (0.008242) + (-0.009253)u_{x} + (-0.000057)u_{xxx} + (-0.006270)u + (-0.031426)u^2 + (-0.023427)uu_{x} + (0.004190)u^2u_{x} + (-0.000036)uu_{xxx} + (-0.000274)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.000228)u^2u_{xxx}
# ====================================================================================================
# SNR =  0.25
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  1
# Iteration: 13. Number of non-zeros:  1
# Iteration: 14. Number of non-zeros:  1
# Iteration: 15. Number of non-zeros:  1
# Iteration: 16. Number of non-zeros:  8
#
# PDEs Predicted by L0:
# u_t = (0.000096)u_{xxx}
# u_t = (0.000096)u_{xxx}
# u_t = (0.000096)u_{xxx}
# u_t = (0.000096)u_{xxx}
# u_t = (0.000096)u_{xxx}
# u_t = (0.000096)u_{xxx}
# u_t = (0.000096)u_{xxx}
# u_t = (0.000096)u_{xxx}
# u_t = (0.000096)u_{xxx}
# u_t = (0.000096)u_{xxx}
# u_t = (0.000096)u_{xxx}
# u_t = (0.000096)u_{xxx}
# u_t = (0.000096)u_{xxx}
# u_t = (0.000096)u_{xxx}
# u_t = (0.000096)u_{xxx}
# u_t = (0.008234) + (-0.001094)u_{x} + (0.000106)u_{xxx} + (0.001405)u + (-0.050864)u^2 + (-0.032255)uu_{x} + (-0.000256)uu_{xxx} + (-0.000097)u^2u_{xxx}
#
# Desired PDE:  u_t = (0.000096)u_{xxx}
# ====================================================================================================
# SNR =  0.2
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  1
# Iteration: 13. Number of non-zeros:  1
# Iteration: 14. Number of non-zeros:  1
# Iteration: 15. Number of non-zeros:  1
# Iteration: 16. Number of non-zeros:  1
# Iteration: 17. Number of non-zeros:  1
# Iteration: 18. Number of non-zeros:  1
# Iteration: 19. Number of non-zeros:  11
#
# PDEs Predicted by L0:
# u_t = (-0.001930)uu_{xx}
# u_t = (-0.001932)uu_{xx}
# u_t = (-0.001932)uu_{xx}
# u_t = (-0.001932)uu_{xx}
# u_t = (-0.001932)uu_{xx}
# u_t = (-0.001932)uu_{xx}
# u_t = (-0.001932)uu_{xx}
# u_t = (-0.001932)uu_{xx}
# u_t = (-0.001932)uu_{xx}
# u_t = (-0.001932)uu_{xx}
# u_t = (-0.001932)uu_{xx}
# u_t = (-0.001932)uu_{xx}
# u_t = (-0.001932)uu_{xx}
# u_t = (-0.001932)uu_{xx}
# u_t = (-0.001932)uu_{xx}
# u_t = (-0.001932)uu_{xx}
# u_t = (-0.001932)uu_{xx}
# u_t = (-0.001932)uu_{xx}
# u_t = (-0.004722)u_{x} + (0.000475)u_{xx} + (-0.000054)u_{xxx} + (-0.008800)u + (-0.038042)u^2 + (-0.013824)uu_{x} + (-0.016809)u^2u_{x} + (-0.002318)uu_{xx} + (-0.002009)u^2u_{xx} + (-0.000115)uu_{xxx} + (-0.000140)u^2u_{xxx}
#
# Desired PDE:  u_t = (-0.001932)uu_{xx}
# ====================================================================================================
# SNR =  0.1
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  1
# Iteration: 3. Number of non-zeros:  1
# Iteration: 4. Number of non-zeros:  1
# Iteration: 5. Number of non-zeros:  1
# Iteration: 6. Number of non-zeros:  1
# Iteration: 7. Number of non-zeros:  1
# Iteration: 8. Number of non-zeros:  1
# Iteration: 9. Number of non-zeros:  1
# Iteration: 10. Number of non-zeros:  1
# Iteration: 11. Number of non-zeros:  1
# Iteration: 12. Number of non-zeros:  1
# Iteration: 13. Number of non-zeros:  1
# Iteration: 14. Number of non-zeros:  1
# Iteration: 15. Number of non-zeros:  1
# Iteration: 16. Number of non-zeros:  1
# Iteration: 17. Number of non-zeros:  1
# Iteration: 18. Number of non-zeros:  10
#
# PDEs Predicted by L0:
# u_t = (0.000040)u^2u_{xxx}
# u_t = (0.000040)u^2u_{xxx}
# u_t = (0.000040)u^2u_{xxx}
# u_t = (0.000040)u^2u_{xxx}
# u_t = (0.000040)u^2u_{xxx}
# u_t = (0.000040)u^2u_{xxx}
# u_t = (0.000040)u^2u_{xxx}
# u_t = (0.000040)u^2u_{xxx}
# u_t = (0.000040)u^2u_{xxx}
# u_t = (0.000040)u^2u_{xxx}
# u_t = (0.000040)u^2u_{xxx}
# u_t = (0.000040)u^2u_{xxx}
# u_t = (0.000040)u^2u_{xxx}
# u_t = (0.000040)u^2u_{xxx}
# u_t = (0.000040)u^2u_{xxx}
# u_t = (0.000040)u^2u_{xxx}
# u_t = (0.000040)u^2u_{xxx}
# u_t = (-0.006086) + (0.003777)u_{x} + (0.000027)u_{xxx} + (-0.015682)u + (0.014480)u^2 + (0.000514)uu_{x} + (0.002956)u^2u_{x} + (-0.000303)u^2u_{xx} + (-0.000021)uu_{xxx} + (0.000048)u^2u_{xxx}
#
# Desired PDE:  u_t = (0.000040)u^2u_{xxx}

# %%
# KDV equation ut = -6uux -1 uxxx

pred_coefficients=[]

snrs = ["No noise",20000,15000]

for j in range(len(snrs)):
    print("="*100)
    print("SNR = ",snrs[j])

    # Loading u,x,t
    path = data_path+"/3_"+str(j)+".pkl"
    sols,descr = discover_pde(path)
    print("\nPDEs Predicted by L0: ")
    for i in range(len(sols)):
        print(return_pde(sols[i]["B"], descr))
# Out:
# ====================================================================================================
# SNR =  No noise
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  3
# Iteration: 3. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.906788)u_{x}
# u_t = (-0.535566)u_{x} + (-0.323605)u_{xxx} + (-2.227135)uu_{x}
# u_t = (-0.524450)u_{x} + (-0.382345)u_{xxx} + (-1.795077)uu_{x} + (-3.188416)u^2u_{x} + (-0.235747)uu_{xxx} + (-0.502226)u^2u_{xxx}
# ====================================================================================================
# SNR =  20000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  3
# Iteration: 4. Number of non-zeros:  4
# Iteration: 5. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.905135)u_{x}
# u_t = (-0.698212)u_{x} + (-0.800076)uu_{x}
# u_t = (-0.689303)u_{x} + (-0.031075)u_{xxx} + (-0.917609)uu_{x}
# u_t = (-0.665591)u_{x} + (-0.022803)u_{xxx} + (-1.108977)uu_{x} + (-0.128679)uu_{xxx}
# u_t = (-0.670075)u_{x} + (-0.022930)u_{xxx} + (-1.021916)uu_{x} + (-0.271072)u^2u_{x} + (-0.110528)uu_{xxx} + (-0.093429)u^2u_{xxx}
# ====================================================================================================
# SNR =  15000
# Preprocessing Data.
# BnB Started.
# Iteration: 1. Number of non-zeros:  1
# Iteration: 2. Number of non-zeros:  2
# Iteration: 3. Number of non-zeros:  3
# Iteration: 4. Number of non-zeros:  4
# Iteration: 5. Number of non-zeros:  6
#
# PDEs Predicted by L0:
# u_t = (-0.904582)u_{x}
# u_t = (-0.696460)u_{x} + (-0.805068)uu_{x}
# u_t = (-0.690537)u_{x} + (-0.028197)u_{xxx} + (-0.905463)uu_{x}
# u_t = (-0.669710)u_{x} + (-0.021219)u_{xxx} + (-1.072153)uu_{x} + (-0.110728)uu_{xxx}
# u_t = (-0.672360)u_{x} + (-0.021521)u_{xxx} + (-1.015668)uu_{x} + (-0.175532)u^2u_{x} + (-0.086682)uu_{xxx} + (-0.088002)u^2u_{xxx}
